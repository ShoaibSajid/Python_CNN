# %% [markdown]
# <a href="https://colab.research.google.com/github/ShoaibSajid/Python_CNN/blob/main/Python_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd ~
![ ! -d "./Python_CNN" ] && echo "Github Repo DOES NOT exists."
![ ! -d "./Python_CNN" ] && git clone https://github.com/ShoaibSajid/Python_CNN
![ -d "./Python_CNN" ] && echo "Github Repo exist."
# %cd Python_CNN
# %pip install -r requirements.txt
# !echo 
# !echo List of files
# !ls
# Out:
# /root
# Github Repo exist.
# /root/Python_CNN
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: mnist==0.2.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: numpy==1.16.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (1.16.3)
# Requirement already satisfied: keras==2.2.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 3)) (2.2.4)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4->-r requirements.txt (line 3)) (1.15.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4->-r requirements.txt (line 3)) (3.1.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4->-r requirements.txt (line 3)) (1.5.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4->-r requirements.txt (line 3)) (6.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4->-r requirements.txt (line 3)) (1.1.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4->-r requirements.txt (line 3)) (1.0.8)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras==2.2.4->-r requirements.txt (line 3)) (1.5.2)
#
# List of files
# cnn_keras.py	     conv.py	  linear_biases.npy   relu.py		weights
# cnn.py		     data.csv	  linear_filters.npy  requirements.txt
# cnn_torch.py	     fc.py	  maxpool.py	      soft_fc.py
# conv_filters_3d.npy  filters.npy  __pycache__	      softmax.py
# conv_filters.npy     LICENSE	  README.md	      softmax_test.py

# %%
# Importing libraries

from matplotlib.pyplot import *
import torch.nn as nn
from tqdm import tqdm
import numpy as np
import pickle
import torch
import os
import mnist
from torch.cuda import amp

os.environ["CUDA_VISIBLE_DEVICES"]=""
device = "cpu"
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
# Define Model
class simple_network(nn.Module):
    def __init__(self):
        super(simple_network, self).__init__()
        self.conv0   = nn.Conv2d    (   1,  8,   kernel_size=(3, 3),     bias=False  , padding=1)   
        self.max0    = nn.MaxPool2d (            kernel_size=(2,2)                   )   
        self.conv1   = nn.Conv2d    (   8,  16,  kernel_size=(3, 3),     bias=False , padding=1 )   
        self.max1    = nn.MaxPool2d (            kernel_size=(2,2)                   )   
        self.flat    = nn.Flatten   (                                                )   
        self.linear0 = nn.Linear    (            784,  784                           )
        self.linear1 = nn.Linear    (            784,  10                            )
        self.soft    = nn.Softmax   (            dim=1                               )
        
        self.debug=False
        

    def forward(self,x):
        x=x.to(torch.device("cpu"))
        x_conv0      = self.conv0     (   x              )  
        x_max0       = self.max0      (   x_conv0        )
        x_conv1      = self.conv1     (   x_max0         )  
        x_max1       = self.max1      (   x_conv1        )
        x_flat       = self.flat      (   x_max1         )
        x_linear0    = self.linear0   (   x_flat         )
        x_linear1    = self.linear1   (   x_linear0      )
        x_prob       = self.soft      (   x_linear1      )

        # TODO: Fix Learning Rate and Gradient Descent Method, check batch size
        if self.debug:
            self.debug=False
            im=x[0][0]
            print(f"Input Image: {im[-4]}\n")
            
            print(f"conv0 filters: {model.state_dict()['conv0.weight'][0][0]}\n")
            
            print(f"x_conv0 : {x_conv0[0,0,:,:][-1]}\n")

            print(f"MaxPool0: {x_max0[0,0][-1]}\n")
            
            print(f"conv1 filters: {model.state_dict()['conv1.weight'][0][0]}\n")
            
            print(f"x_conv1 : {x_conv1[0,0,:,:][-1]}\n")

            print(f"MaxPool1: {x_max1[0,0][-1]}\n")
            
            print(f"FC0 Weight: {model.state_dict()['linear0.weight'][0][:10]}\n")
            
            print(f"FC0 Output: {x_linear0[0,:10]}\n")
            
            print(f"FC1 Weight: {model.state_dict()['linear1.weight'][0][:10]}\n")
            
            print(f"FC1 Output: {x_linear1[0,:10]}\n")
            
            print(f"SoftMax Output: {x_prob}\n")
            
        return x_prob

# %%
# Initialize model and print

model = simple_network()
model.double()
print(model)
# Out:
# simple_network(
#   (conv0): Conv2d(1, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (max0): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (conv1): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (max1): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (linear0): Linear(in_features=784, out_features=784, bias=True)
#   (linear1): Linear(in_features=784, out_features=10, bias=True)
#   (soft): Softmax(dim=1)
# )

# %%
# Hyper Parameters

n_epochs = 3
# batch_size_train = 64
# batch_size_test = 1000
learning_rate = 0.005
momentum = 0
log_interval = 1
torch.backends.cudnn.enabled = False

# %%
# Optimizer
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate,momentum=momentum)

# %%
# Scaler
scaler = amp.GradScaler()
# Out:
# /home/msis/anaconda3/lib/python3.8/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")

# %%
# Loss Function
calculate_loss = nn.CrossEntropyLoss()
# calculate_loss_nlll = nn.NLLLoss()

# %%
# Define Dataset
train_images = mnist.train_images()
train_labels = mnist.train_labels()
test_images = mnist.test_images()
test_labels = mnist.test_labels()
train_images = (train_images / 255) - 0.5
test_images = (test_images / 255) - 0.5
train_images = np.expand_dims(train_images, axis=3)
test_images = np.expand_dims(test_images, axis=3)

# %%
# Counters to keep track of losses
train_losses = []
train_counter = []
test_losses = []
test_counter = [i*len(train_labels) for i in range(n_epochs + 1)]

# %%
# Function for copying weights from basic model 
def copy_weights():
    # TODO: To copy filter weights
    name = "weights/debug.pkl"
    print(f"Loading weights from {name}")
    weight_file = open(name, "rb")
    weights = pickle.load(weight_file)
    print(f"\nLoading weights from {name} file")
    
    fconv0   = weights["conv0"]  
    fconv1   = weights["conv1"]  
    flinear0 = weights["fc0_weights"]
    blinear0 = weights["fc0_biases" ]
    flinear1 = weights["fc1_weights"]
    blinear1 = weights["fc1_biases" ]

    for i in range(fconv0.shape[0]):
        model.state_dict()['conv0.weight'][i][0]     = torch.from_numpy(fconv0[i]).double()
        print(f"Weights for Conv0 Filter {i} are {model.state_dict()['conv0.weight'][i][0][0]}   ")

    for i in range(fconv1.shape[0]):
        for j in range(fconv1.shape[3]):
            model.state_dict()['conv1.weight'][i,j,:,:]     = torch.from_numpy(fconv1[i,:,:,j]).double()
        print(f"Weights for Conv1 Filter {i} are {model.state_dict()['conv1.weight'][i][0][0]}   ")

    for i in range(flinear0.shape[1]):
        model.state_dict()['linear0.weight'][i]      = torch.from_numpy(flinear0[:,i]).double()
        if i<10: print(f"Weights for Linear Filter {i} are {model.state_dict()['linear0.weight'][i][:5]} ")
        
    for i in range(blinear0.shape[0]):
        model.state_dict()['linear0.bias'][i]        = torch.tensor(blinear0[i]).double()
        if i<10: print(f"Weights for Linear Bias   {i} are {model.state_dict()['linear0.bias'][i]}   ")
    
    for i in range(flinear1.shape[1]):
        model.state_dict()['linear1.weight'][i]      = torch.from_numpy(flinear1[:,i]).double()
        if i<10: print(f"Weights for Linear Filter {i} are {model.state_dict()['linear1.weight'][i][:5]} ")
        
    for i in range(blinear1.shape[0]):
        model.state_dict()['linear1.bias'][i]        = torch.tensor(blinear1[i]).double()
        if i<10: print(f"Weights for Linear Bias   {i} are {model.state_dict()['linear1.bias'][i]}   ")

# %%
# Define the Train function
def train(epoch):
    model.train()
    model.double()
    copy_weights()
    for batch_idx, (image, target) in enumerate(zip(train_images,train_labels)):
        optimizer.zero_grad()
        
        # Prepare Image
        img_numpy  = image[:,:,0]
        img_tensor = torch.tensor(img_numpy).double()
        img_for_model = img_tensor.unsqueeze(0).unsqueeze(0).double()

        # Prepare label
        label_vector = torch.zeros(1,10)
        label_vector[:,target]=1

        # Model Output
        output = model(img_for_model.double())
        
        # Calculate Loss
        loss = calculate_loss(label_vector, output)
        # loss_nlll = calculate_loss_nlll(label_vector, output)
        
        # Calculate gradients
        # scaler.scale(loss).backward()
        loss.backward()
        
        # Update weights
        # optimizer.step()
        scaler.step(optimizer)
        scaler.update()
        
        grad_bank = {}
        for idx, param in enumerate(model.parameters()):
            # print(f"Parameter: {param.name}")
            # print(f"Parameter: {param.names}")
            # print(f"Parameter: {param.grad.data}") 
            grad_bank[f"layer_{idx}"] = param.grad.data
        
        if model.debug = print(grad_bank['layer_5'])
            
            
        # if batch_idx % log_interval == 0:
        print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(epoch, batch_idx * len(image), len(train_images),100. * batch_idx / len(train_images), loss.item()),end='\r')
        # train_losses.append(loss.item())
        # train_counter.append((batch_idx*64) + ((epoch-1)*len(train_loader.dataset)))
        # torch.save(network.state_dict(), '/results/model.pth')
        # torch.save(optimizer.state_dict(), '/results/optimizer.pth')

# %%
# Run Training
for epoch in range(1, n_epochs + 1):
    train(epoch)
# Out:
# Loading weights from weights/debug.pkl
#
# Loading weights from weights/debug.pkl file
# Weights for Conv0 Filter 0 are tensor([0.8010, 0.4643, 0.4578], dtype=torch.float64)
# Weights for Conv0 Filter 1 are tensor([ 0.0975,  0.2411, -0.0667], dtype=torch.float64)
# Weights for Conv0 Filter 2 are tensor([ 0.1927, -0.7409, -0.5107], dtype=torch.float64)
# Weights for Conv0 Filter 3 are tensor([ 0.2085, -0.0704,  0.1417], dtype=torch.float64)
# Weights for Conv0 Filter 4 are tensor([0.7292, 0.4683, 0.6256], dtype=torch.float64)
# Weights for Conv0 Filter 5 are tensor([-0.1895, -0.4578,  0.2332], dtype=torch.float64)
# Weights for Conv0 Filter 6 are tensor([ 0.1651, -0.5414,  0.1606], dtype=torch.float64)
# Weights for Conv0 Filter 7 are tensor([-0.1284, -0.2311,  0.0898], dtype=torch.float64)
# Weights for Conv1 Filter 0 are tensor([-0.1121, -0.2705, -0.1608], dtype=torch.float64)
# Weights for Conv1 Filter 1 are tensor([ 0.1453,  0.0431, -0.1738], dtype=torch.float64)
# Weights for Conv1 Filter 2 are tensor([0.0813, 0.1152, 0.1309], dtype=torch.float64)
# Weights for Conv1 Filter 3 are tensor([-0.0610, -0.0821, -0.0050], dtype=torch.float64)
# Weights for Conv1 Filter 4 are tensor([0.0603, 0.2390, 0.3440], dtype=torch.float64)
# Weights for Conv1 Filter 5 are tensor([-0.2049, -0.0692,  0.1493], dtype=torch.float64)
# Weights for Conv1 Filter 6 are tensor([-0.1915, -0.0850,  0.2653], dtype=torch.float64)
# Weights for Conv1 Filter 7 are tensor([-0.0976,  0.1633, -0.1650], dtype=torch.float64)
# Weights for Conv1 Filter 8 are tensor([-0.0255,  0.1712,  0.2037], dtype=torch.float64)
# Weights for Conv1 Filter 9 are tensor([ 0.2873,  0.1080, -0.2518], dtype=torch.float64)
# Weights for Conv1 Filter 10 are tensor([-0.1893,  0.0170,  0.0952], dtype=torch.float64)
# Weights for Conv1 Filter 11 are tensor([-0.0734, -0.0307,  0.1148], dtype=torch.float64)
# Weights for Conv1 Filter 12 are tensor([ 0.2034,  0.3277, -0.0890], dtype=torch.float64)
# Weights for Conv1 Filter 13 are tensor([ 0.2432, -0.0078,  0.0188], dtype=torch.float64)
# Weights for Conv1 Filter 14 are tensor([0.0318, 0.2024, 0.2438], dtype=torch.float64)
# Weights for Conv1 Filter 15 are tensor([-0.1465, -0.1630,  0.2060], dtype=torch.float64)
# Weights for Linear Filter 0 are tensor([ 0.0007, -0.0003,  0.0004, -0.0009, -0.0007], dtype=torch.float64)
# Weights for Linear Filter 1 are tensor([ 4.3590e-04,  2.1526e-05,  1.5253e-03,  8.6340e-04, -2.6636e-03],
#        dtype=torch.float64)
# Weights for Linear Filter 2 are tensor([-0.0020, -0.0069, -0.0008,  0.0081, -0.0011], dtype=torch.float64)
# Weights for Linear Filter 3 are tensor([0.0005, 0.0004, 0.0004, 0.0016, 0.0037], dtype=torch.float64)
# Weights for Linear Filter 4 are tensor([-0.0005, -0.0033, -0.0044, -0.0045, -0.0035], dtype=torch.float64)
# Weights for Linear Filter 5 are tensor([-2.1713e-04,  1.4643e-05, -1.2511e-03, -3.7259e-03,  4.9229e-04],
#        dtype=torch.float64)
# Weights for Linear Filter 6 are tensor([ 0.0013,  0.0035,  0.0024, -0.0016,  0.0016], dtype=torch.float64)
# Weights for Linear Filter 7 are tensor([ 0.0013,  0.0022, -0.0011,  0.0012,  0.0023], dtype=torch.float64)
# Weights for Linear Filter 8 are tensor([ 0.0016, -0.0022,  0.0021, -0.0026, -0.0009], dtype=torch.float64)
# Weights for Linear Filter 9 are tensor([ 0.0006, -0.0005,  0.0044, -0.0053, -0.0009], dtype=torch.float64)
# Weights for Linear Bias   0 are -0.00046320779613416726
# Weights for Linear Bias   1 are 0.0003919485210910878
# Weights for Linear Bias   2 are 0.0028212366758244836
# Weights for Linear Bias   3 are -0.00022293160912447124
# Weights for Linear Bias   4 are 0.0003204748671130967
# Weights for Linear Bias   5 are -0.0011638217770218063
# Weights for Linear Bias   6 are -0.0008822436838608358
# Weights for Linear Bias   7 are -0.00101088077319044
# Weights for Linear Bias   8 are -0.0004995192767907489
# Weights for Linear Bias   9 are -0.0013258839135347337
# Weights for Linear Filter 0 are tensor([-0.0286,  0.0568, -0.0018, -0.0471, -0.0423], dtype=torch.float64)
# Weights for Linear Filter 1 are tensor([0.0157, 0.0288, 0.1152, 0.0456, 0.0833], dtype=torch.float64)
# Weights for Linear Filter 2 are tensor([ 0.0024,  0.0142,  0.0295, -0.0161, -0.0369], dtype=torch.float64)
# Weights for Linear Filter 3 are tensor([ 0.0175, -0.0164, -0.0134, -0.0226, -0.0404], dtype=torch.float64)
# Weights for Linear Filter 4 are tensor([-0.0631, -0.0553, -0.0113, -0.0163,  0.0788], dtype=torch.float64)
# Weights for Linear Filter 5 are tensor([ 0.0305, -0.0120, -0.0717,  0.0055,  0.0091], dtype=torch.float64)
# Weights for Linear Filter 6 are tensor([-0.0256,  0.0063, -0.0327, -0.0006,  0.0409], dtype=torch.float64)
# Weights for Linear Filter 7 are tensor([-0.0166, -0.0017,  0.0917,  0.0268, -0.0391], dtype=torch.float64)
# Weights for Linear Filter 8 are tensor([ 0.0740,  0.0011, -0.0624, -0.0074, -0.0283], dtype=torch.float64)
# Weights for Linear Filter 9 are tensor([-0.0035, -0.0204, -0.0419,  0.0283, -0.0311], dtype=torch.float64)
# Weights for Linear Bias   0 are -0.11587261720595748
# Weights for Linear Bias   1 are -0.04656987548463663
# Weights for Linear Bias   2 are 0.0379505030029265
# Weights for Linear Bias   3 are 0.014913312352529668
# Weights for Linear Bias   4 are -0.007190711171645281
# Weights for Linear Bias   5 are 0.001266817455354847
# Weights for Linear Bias   6 are -0.03627993599968686
# Weights for Linear Bias   7 are 0.026793289485101308
# Weights for Linear Bias   8 are 0.03751810153549915
# Weights for Linear Bias   9 are 0.08747111603051437
# tensor([ 3.0710e-05,  1.5119e-07,  1.5057e-05,  9.1034e-02,  5.1493e-09,
#         -9.1288e-02,  1.7400e-07,  1.0264e-05,  1.6549e-04,  3.2031e-05],
#        dtype=torch.float64)
# tensor([ 1.0515e-05,  1.5662e-07,  2.1858e-05,  9.1035e-02,  7.2147e-09,
#         -9.1288e-02,  5.6167e-07,  2.1429e-05,  1.6554e-04,  3.2992e-05],
#        dtype=torch.float64)
# tensor([ 1.0649e-05,  2.2489e-05,  2.5755e-05,  9.1075e-02, -4.9031e-04,
#         -9.1272e-02,  2.9305e-05,  9.0910e-05,  1.7064e-04,  3.3763e-04],
#        dtype=torch.float64)
# tensor([ 1.3839e-05, -1.6072e-03,  9.0271e-04,  9.1084e-02, -3.0151e-04,
#         -9.1272e-02,  3.6924e-05,  3.0573e-04,  5.0016e-04,  3.3809e-04],
#        dtype=torch.float64)
# tensor([ 1.7062e-04, -8.5476e-04,  9.1677e-04,  9.1272e-02,  1.5085e-01,
#         -9.0676e-02,  1.5192e-04,  1.0937e-03,  1.0353e-02, -1.6328e-01],
#        dtype=torch.float64)
# tensor([ 2.2431e-04, -8.5397e-04, -3.5314e-04,  9.2152e-02,  1.5085e-01,
#         -9.0675e-02,  1.5204e-04,  1.1041e-03,  1.0675e-02, -1.6328e-01],
#        dtype=torch.float64)
# tensor([ 0.0002, -0.0054,  0.0025,  0.0932,  0.1509, -0.0907,  0.0002,  0.0011,
#          0.0112, -0.1633], dtype=torch.float64)
# tensor([ 0.0002, -0.0054,  0.0027,  0.0924,  0.1509, -0.0906,  0.0002,  0.0011,
#          0.0117, -0.1632], dtype=torch.float64)
# tensor([ 0.0002, -0.0070,  0.0033,  0.0926,  0.1511, -0.0906,  0.0003,  0.0014,
#          0.0118, -0.1632], dtype=torch.float64)
# tensor([ 0.0002, -0.0068,  0.0034,  0.0926,  0.1506, -0.0906,  0.0004,  0.0014,
#          0.0120, -0.1632], dtype=torch.float64)
# tensor([ 0.0002, -0.0068,  0.0036,  0.0917,  0.1506, -0.0905,  0.0004,  0.0014,
#          0.0125, -0.1632], dtype=torch.float64)
# tensor([ 0.0018,  0.0118,  0.0042,  0.0930,  0.1506, -0.1255,  0.0012,  0.0015,
#          0.0246, -0.1631], dtype=torch.float64)
# tensor([ 0.0018,  0.0118,  0.0042,  0.0930,  0.1506, -0.1255,  0.0012,  0.0015,
#          0.0246, -0.1631], dtype=torch.float64)
# tensor([ 0.0022,  0.0118,  0.0042,  0.0930,  0.1508, -0.1255,  0.0004,  0.0015,
#          0.0247, -0.1631], dtype=torch.float64)
# tensor([ 0.0022,  0.0098,  0.0053,  0.0931,  0.1509, -0.1255,  0.0004,  0.0021,
#          0.0249, -0.1631], dtype=torch.float64)
# tensor([ 0.0023,  0.0099,  0.0053,  0.0931,  0.1509, -0.1255,  0.0004, -0.0097,
#          0.0249, -0.1515], dtype=torch.float64)
# tensor([ 0.0035,  0.0099,  0.0028,  0.0940,  0.1509, -0.1255,  0.0006, -0.0097,
#          0.0250, -0.1515], dtype=torch.float64)
# tensor([ 0.0054,  0.0308,  0.0112,  0.1127,  0.1512, -0.1251,  0.0006, -0.0085,
#         -0.0331, -0.1453], dtype=torch.float64)
# tensor([ 0.0100,  0.0309,  0.0114,  0.1131,  0.1515, -0.1161, -0.0144, -0.0085,
#         -0.0327, -0.1453], dtype=torch.float64)
# tensor([ 0.0104,  0.0507,  0.0119,  0.1985,  0.1531, -0.1142, -0.0144,  0.0723,
#         -0.0073, -0.3611], dtype=torch.float64)
# tensor([ 0.0104,  0.0507,  0.0119,  0.1985,  0.1529, -0.1142, -0.0144,  0.0723,
#         -0.0073, -0.3609], dtype=torch.float64)
# tensor([ 0.0103,  0.0507,  0.0120,  0.1986,  0.1529, -0.1142, -0.0144,  0.0723,
#         -0.0073, -0.3609], dtype=torch.float64)
# tensor([ 0.0117,  0.0610,  0.0144,  0.1994,  0.3182, -0.1141, -0.0141,  0.0845,
#          0.0022, -0.5633], dtype=torch.float64)
# tensor([ 0.0117,  0.0590,  0.0152,  0.1994,  0.3186, -0.1141, -0.0141,  0.0851,
#          0.0024, -0.5633], dtype=torch.float64)
# tensor([ 0.0121, -0.1465,  0.0216,  0.3943,  0.3186, -0.1126, -0.0133,  0.0853,
#          0.0031, -0.5627], dtype=torch.float64)
# tensor([ 0.0124, -0.1465, -0.1049,  0.4727,  0.3186, -0.1126, -0.0133,  0.0853,
#          0.0510, -0.5627], dtype=torch.float64)
# tensor([ 0.0124, -0.1445, -0.1049,  0.4738,  0.3098, -0.1125, -0.0132,  0.0857,
#          0.0516, -0.5581], dtype=torch.float64)
# tensor([ 0.0124, -0.1445, -0.1049,  0.4738,  0.3098, -0.1125, -0.0132,  0.0857,
#          0.0516, -0.5581], dtype=torch.float64)
# tensor([ 0.0251, -0.1444, -0.1818,  0.4764,  0.3098, -0.1125, -0.0132,  0.1108,
#          0.0879, -0.5581], dtype=torch.float64)
# tensor([ 0.0252, -0.0275, -0.1779,  0.4798,  0.3307, -0.1124, -0.0132, -0.0582,
#          0.0911, -0.5376], dtype=torch.float64)
# tensor([ 0.0252, -0.0273, -0.1753,  0.4768,  0.3307, -0.1124, -0.0132, -0.0581,
#          0.0912, -0.5376], dtype=torch.float64)
# tensor([ 0.0268, -0.0149, -0.1672,  0.5172,  0.3307, -0.1123, -0.0132, -0.0581,
#          0.0284, -0.5372], dtype=torch.float64)
# tensor([ 0.0268, -0.0149, -0.1672,  0.5172,  0.3307, -0.1123, -0.0133, -0.0581,
#          0.0284, -0.5372], dtype=torch.float64)
# tensor([ 0.0269, -0.0129, -0.1671,  0.5370,  0.3323, -0.1121, -0.0133,  0.1613,
#          0.0340, -0.7861], dtype=torch.float64)
# tensor([ 0.0242, -0.0128, -0.1667,  0.5370,  0.3323, -0.1121, -0.0127,  0.1614,
#          0.0356, -0.7861], dtype=torch.float64)
# tensor([ 0.0244,  0.0020, -0.1665,  0.5605,  0.3325, -0.1531, -0.0127,  0.1615,
#          0.0374, -0.7859], dtype=torch.float64)
# tensor([ 0.0244,  0.0020, -0.1664,  0.5605,  0.3326, -0.1531, -0.0137,  0.1615,
#          0.0381, -0.7859], dtype=torch.float64)
# tensor([ 0.0242,  0.0020, -0.1664,  0.5605,  0.3326, -0.1531, -0.0135,  0.1615,
#          0.0381, -0.7859], dtype=torch.float64)
# tensor([ 0.0242,  0.0021,  0.0247,  0.5929,  0.3326, -0.1531, -0.0135, -0.0646,
#          0.0387, -0.7839], dtype=torch.float64)
# tensor([ 0.0252,  0.0021,  0.0248,  0.5929,  0.3332, -0.1531, -0.0157, -0.0646,
#          0.0390, -0.7839], dtype=torch.float64)
# tensor([ 0.0252,  0.0009,  0.0252,  0.5932,  0.3333, -0.1531, -0.0157, -0.0642,
#          0.0391, -0.7839], dtype=torch.float64)
# tensor([ 0.0253,  0.0010,  0.0298,  0.6064,  0.3333, -0.1531, -0.0157, -0.0642,
#          0.0209, -0.7838], dtype=torch.float64)
# tensor([ 0.0254,  0.0030,  0.0300,  0.6092,  0.3333, -0.1531, -0.0157, -0.0850,
#          0.0210, -0.7681], dtype=torch.float64)
# tensor([ 0.0254,  0.0041,  0.0303,  0.6627,  0.3341, -0.1526, -0.0157, -0.0573,
#          0.0380, -0.8688], dtype=torch.float64)
# tensor([ 0.0254,  0.0041,  0.0305,  0.6622,  0.3341, -0.1526, -0.0157, -0.0573,
#          0.0380, -0.8688], dtype=torch.float64)
# tensor([ 0.0254,  0.0041,  0.0305,  0.6629,  0.3420, -0.1523, -0.0157, -0.0562,
#          0.0385, -0.8793], dtype=torch.float64)
# tensor([ 0.0255,  0.0042,  0.0309,  0.6658,  0.3420, -0.1520, -0.0157, -0.0562,
#          0.0344, -0.8788], dtype=torch.float64)
# tensor([ 0.0255,  0.0042,  0.0309,  0.6660,  0.3421, -0.1526, -0.0157, -0.0562,
#          0.0348, -0.8788], dtype=torch.float64)
# tensor([ 0.0255,  0.0044,  0.0309,  0.6753,  0.3421, -0.1478, -0.0157, -0.0561,
#          0.0365, -0.8951], dtype=torch.float64)
# tensor([ 0.0255,  0.0044,  0.0309,  0.6744,  0.3421, -0.1473, -0.0157, -0.0561,
#          0.0368, -0.8951], dtype=torch.float64)
# tensor([ 0.0255,  0.0044,  0.0309,  0.6738,  0.3421, -0.1468, -0.0157, -0.0561,
#          0.0368, -0.8950], dtype=torch.float64)
# tensor([ 0.0255,  0.0044,  0.0309,  0.6738,  0.3421, -0.1468, -0.0157, -0.0561,
#          0.0368, -0.8950], dtype=torch.float64)
# tensor([ 0.0265,  0.0044,  0.0309,  0.6739,  0.3421, -0.1468, -0.0157, -0.0580,
#          0.0368, -0.8941], dtype=torch.float64)
# tensor([ 0.0265,  0.0080,  0.0310,  0.6793,  0.2984, -0.1417, -0.0150, -0.0455,
#          0.0383, -0.8793], dtype=torch.float64)
# tensor([ 0.0265,  0.0080,  0.0310,  0.6864,  0.3193, -0.1409, -0.0150,  0.0995,
#          0.0491, -1.0639], dtype=torch.float64)
# tensor([ 0.0266,  0.0081,  0.0314,  0.6917,  0.3193, -0.1409, -0.0150,  0.1001,
#          0.0374, -1.0587], dtype=torch.float64)
# tensor([ 0.0264,  0.0081,  0.0314,  0.6917,  0.3193, -0.1408, -0.0150,  0.1001,
#          0.0375, -1.0587], dtype=torch.float64)
# tensor([ 0.0266,  0.0083,  0.0315,  0.6981,  0.3492, -0.1403, -0.0150,  0.1194,
#          0.0399, -1.1178], dtype=torch.float64)
# tensor([ 0.0266,  0.0084,  0.0315,  0.6982,  0.3475, -0.1403, -0.0150,  0.1194,
#          0.0400, -1.1162], dtype=torch.float64)
# tensor([ 0.0266,  0.0069,  0.0324,  0.6982,  0.3477, -0.1403, -0.0149,  0.1194,
#          0.0404, -1.1162], dtype=torch.float64)
# tensor([ 0.0266,  0.0069,  0.0325,  0.6982,  0.3464, -0.1403, -0.0141,  0.1195,
#          0.0404, -1.1160], dtype=torch.float64)
# tensor([ 0.0266,  0.0112,  0.0325,  0.6982,  0.3399, -0.1403, -0.0141,  0.1200,
#          0.0410, -1.1151], dtype=torch.float64)
# tensor([ 0.0286,  0.0112,  0.0325,  0.6983,  0.3400, -0.1390, -0.0272,  0.1200,
#          0.0508, -1.1151], dtype=torch.float64)
# tensor([ 0.0264,  0.0112,  0.0326,  0.7003,  0.3400, -0.1390, -0.0272,  0.1200,
#          0.0508, -1.1150], dtype=torch.float64)
# tensor([ 0.0268,  0.0112,  0.0338,  0.7003,  0.3245, -0.1390, -0.0139,  0.1200,
#          0.0512, -1.1148], dtype=torch.float64)
# tensor([ 0.0268,  0.0113,  0.0338,  0.7006,  0.3245, -0.1397, -0.0139,  0.1200,
#          0.0514, -1.1148], dtype=torch.float64)
# tensor([ 0.0278,  0.0113,  0.0338,  0.7006,  0.3245, -0.1395, -0.0152,  0.1200,
#          0.0514, -1.1148], dtype=torch.float64)
# tensor([ 0.0279, -0.0024,  0.0387,  0.7030,  0.3246, -0.1394, -0.0151,  0.1241,
#          0.0536, -1.1148], dtype=torch.float64)
# tensor([ 0.0109, -0.0024,  0.0542,  0.7030,  0.3246, -0.1390, -0.0151,  0.1241,
#          0.0547, -1.1148], dtype=torch.float64)
# tensor([ 0.0099, -0.0024,  0.0543,  0.7032,  0.3246, -0.1390, -0.0151,  0.1241,
#          0.0552, -1.1147], dtype=torch.float64)
# tensor([ 0.0102, -0.1231,  0.1664,  0.7058,  0.3246, -0.1390, -0.0100,  0.1241,
#          0.0558, -1.1147], dtype=torch.float64)
# tensor([ 0.0103, -0.1230,  0.1664,  0.7058,  0.3247, -0.1390, -0.0100,  0.1131,
#          0.0558, -1.1042], dtype=torch.float64)
# tensor([ 0.0103, -0.1249,  0.1674,  0.7059,  0.3248, -0.1390, -0.0099,  0.1138,
#          0.0559, -1.1042], dtype=torch.float64)
# tensor([ 0.0106, -0.1249,  0.1674,  0.7059,  0.3248, -0.1390, -0.0106,  0.1138,
#          0.0561, -1.1042], dtype=torch.float64)
# tensor([ 0.0106, -0.1249,  0.1674,  0.7056,  0.3248, -0.1389, -0.0106,  0.1138,
#          0.0562, -1.1042], dtype=torch.float64)
# tensor([ 0.0102, -0.1249,  0.1675,  0.7060,  0.3248, -0.1389, -0.0106,  0.1138,
#          0.0562, -1.1042], dtype=torch.float64)
# tensor([ 0.0102, -0.1242,  0.1454,  0.7147,  0.3248, -0.1389, -0.0106,  0.1138,
#          0.0689, -1.1042], dtype=torch.float64)
# tensor([ 0.0102, -0.1266,  0.1464,  0.7147,  0.3249, -0.1389, -0.0106,  0.1143,
#          0.0696, -1.1042], dtype=torch.float64)
# tensor([ 0.0102, -0.1364,  0.1549,  0.7150,  0.3252, -0.1389, -0.0105,  0.1148,
#          0.0699, -1.1041], dtype=torch.float64)
# tensor([ 0.0103, -0.1345,  0.1549,  0.7151,  0.3272, -0.1389, -0.0105,  0.0543,
#          0.0700, -1.0478], dtype=torch.float64)
# tensor([ 0.0106, -0.1345,  0.1549,  0.7153,  0.3272, -0.1388, -0.0105,  0.0543,
#          0.0713, -1.0497], dtype=torch.float64)
# tensor([ 0.0101, -0.1345,  0.1550,  0.7153,  0.3272, -0.1388, -0.0105,  0.0543,
#          0.0716, -1.0497], dtype=torch.float64)
# tensor([ 0.0106, -0.1345,  0.1544,  0.7154,  0.3272, -0.1388, -0.0105,  0.0543,
#          0.0717, -1.0497], dtype=torch.float64)
# tensor([ 0.0126, -0.1345,  0.1548,  0.7154,  0.3272, -0.1388, -0.0131,  0.0543,
#          0.0718, -1.0497], dtype=torch.float64)
# tensor([ 0.0126, -0.1345,  0.1550,  0.7155,  0.3272, -0.1388, -0.0131,  0.0539,
#          0.0718, -1.0496], dtype=torch.float64)
# tensor([ 0.0127, -0.1340,  0.1562,  0.7258,  0.3272, -0.1387, -0.0131,  0.0539,
#          0.0595, -1.0495], dtype=torch.float64)
# tensor([ 0.0127, -0.1340,  0.1562,  0.7155,  0.3272, -0.1303, -0.0131,  0.0545,
#          0.0596, -1.0484], dtype=torch.float64)
# tensor([ 0.0129, -0.1340,  0.1562,  0.7155,  0.3366, -0.1302, -0.0131,  0.0566,
#          0.0610, -1.0616], dtype=torch.float64)
# tensor([ 0.0129, -0.1340,  0.1562,  0.7155,  0.3366, -0.1302, -0.0131,  0.0566,
#          0.0610, -1.0616], dtype=torch.float64)
# tensor([ 0.0129, -0.1340,  0.1562,  0.7155,  0.3362, -0.1302, -0.0131,  0.0567,
#          0.0610, -1.0614], dtype=torch.float64)
# tensor([ 0.0129, -0.1340,  0.1562,  0.7155,  0.3363, -0.1302, -0.0131,  0.0567,
#          0.0610, -1.0614], dtype=torch.float64)
# tensor([ 0.0130, -0.1340,  0.1562,  0.7155,  0.3363, -0.1302, -0.0131,  0.0446,
#          0.0610, -1.0494], dtype=torch.float64)
# tensor([ 0.0130, -0.1340,  0.1563,  0.7156,  0.3355, -0.1302, -0.0129,  0.0446,
#          0.0611, -1.0490], dtype=torch.float64)
# tensor([ 0.0142, -0.1339,  0.1563,  0.7157,  0.3356, -0.1300, -0.0155,  0.0446,
#          0.0620, -1.0490], dtype=torch.float64)
# tensor([ 0.0144, -0.1339,  0.1569,  0.7170,  0.3356, -0.1299, -0.0155,  0.0446,
#          0.0568, -1.0461], dtype=torch.float64)
# tensor([ 0.0143, -0.1339,  0.1570,  0.7170,  0.3356, -0.1299, -0.0155,  0.0446,
#          0.0568, -1.0461], dtype=torch.float64)
# tensor([ 0.0143, -0.1338,  0.1571,  0.7173,  0.3356, -0.1299, -0.0155,  0.0433,
#          0.0568, -1.0454], dtype=torch.float64)
# tensor([ 0.0144, -0.1338,  0.1592,  0.7218,  0.3356, -0.1299, -0.0155,  0.0434,
#          0.0497, -1.0450], dtype=torch.float64)
# tensor([ 0.0144, -0.1338,  0.1592,  0.7201,  0.3356, -0.1285, -0.0155,  0.0434,
#          0.0499, -1.0450], dtype=torch.float64)
# tensor([ 0.0144, -0.1403,  0.1614,  0.7202,  0.3360, -0.1285, -0.0155,  0.0472,
#          0.0500, -1.0449], dtype=torch.float64)
# tensor([ 0.0286, -0.1387,  0.1621,  0.7313,  0.3367, -0.2097, -0.0113,  0.0474,
#          0.0769, -1.0234], dtype=torch.float64)
# tensor([ 0.0288, -0.1387,  0.1621,  0.7313,  0.3369, -0.2096, -0.0113,  0.0408,
#          0.0769, -1.0173], dtype=torch.float64)
# tensor([ 0.0288, -0.1395,  0.1626,  0.7313,  0.3369, -0.2096, -0.0112,  0.0409,
#          0.0770, -1.0173], dtype=torch.float64)
# tensor([ 0.0288, -0.1395,  0.1626,  0.7313,  0.3369, -0.2096, -0.0112,  0.0402,
#          0.0770, -1.0166], dtype=torch.float64)
# tensor([ 0.0288, -0.1479,  0.1670,  0.7317,  0.3382, -0.2095, -0.0101,  0.0405,
#          0.0778, -1.0166], dtype=torch.float64)
# tensor([ 0.0289, -0.1537,  0.1679,  0.7317,  0.3384, -0.2095, -0.0088,  0.0405,
#          0.0813, -1.0166], dtype=torch.float64)
# tensor([ 0.0290, -0.1537,  0.1679,  0.7318,  0.3384, -0.2073, -0.0134,  0.0405,
#          0.0833, -1.0166], dtype=torch.float64)
# tensor([ 0.0290, -0.1537,  0.1680,  0.7316,  0.3384, -0.2072, -0.0134,  0.0405,
#          0.0833, -1.0165], dtype=torch.float64)
# tensor([ 0.0210, -0.1537,  0.1757,  0.7316,  0.3384, -0.2070, -0.0134,  0.0405,
#          0.0834, -1.0165], dtype=torch.float64)
# tensor([ 0.0234, -0.1533,  0.1066,  0.7487,  0.3435, -0.2064,  0.0183,  0.0518,
#          0.0836, -1.0162], dtype=torch.float64)
# tensor([ 0.0234, -0.1533,  0.1066,  0.7488,  0.3472, -0.2063,  0.0183,  0.0518,
#          0.0839, -1.0204], dtype=torch.float64)
# tensor([ 0.0234, -0.1533,  0.1066,  0.7476,  0.3472, -0.2062,  0.0183,  0.0518,
#          0.0849, -1.0203], dtype=torch.float64)
# tensor([ 0.0234, -0.1552,  0.1071,  0.7479,  0.3474, -0.2062,  0.0183,  0.0527,
#          0.0850, -1.0203], dtype=torch.float64)
# tensor([ 0.0234, -0.1582,  0.1089,  0.7480,  0.3474, -0.2062,  0.0183,  0.0527,
#          0.0859, -1.0203], dtype=torch.float64)
# tensor([ 0.0234, -0.1582,  0.1089,  0.7480,  0.3474, -0.2062,  0.0183,  0.0527,
#          0.0859, -1.0203], dtype=torch.float64)
# tensor([ 0.0234, -0.1582,  0.1089,  0.7480,  0.3473, -0.2062,  0.0183,  0.0527,
#          0.0859, -1.0202], dtype=torch.float64)
# tensor([ 0.0235, -0.1582,  0.1089,  0.7486,  0.3568, -0.2059,  0.0183,  0.0536,
#          0.0865, -1.0321], dtype=torch.float64)
# tensor([ 0.0256, -0.1582,  0.0498,  0.8053,  0.3568, -0.2059,  0.0183,  0.0536,
#          0.0869, -1.0321], dtype=torch.float64)
# tensor([ 0.0253, -0.1582,  0.0499,  0.8053,  0.3568, -0.2059,  0.0184,  0.0536,
#          0.0869, -1.0321], dtype=torch.float64)
# tensor([ 0.0253, -0.1582,  0.0499,  0.8053,  0.3568, -0.2059,  0.0184,  0.0537,
#          0.0869, -1.0321], dtype=torch.float64)
# tensor([ 0.0270, -0.1582, -0.0903,  0.8272,  0.3568, -0.2059,  0.0184,  0.1700,
#          0.0871, -1.0321], dtype=torch.float64)
# tensor([ 0.0269, -0.1582, -0.0902,  0.8272,  0.3568, -0.2058,  0.0184,  0.1700,
#          0.0871, -1.0321], dtype=torch.float64)
# tensor([ 0.0269, -0.1443, -0.1044,  0.8274,  0.3568, -0.2058,  0.0185,  0.1700,
#          0.0872, -1.0321], dtype=torch.float64)
# tensor([ 0.0269, -0.1443, -0.1044,  0.8274,  0.3568, -0.2058,  0.0185,  0.1689,
#          0.0872, -1.0310], dtype=torch.float64)
# tensor([ 0.0269, -0.1502, -0.1033,  0.8284,  0.3568, -0.2058,  0.0185,  0.1723,
#          0.0874, -1.0309], dtype=torch.float64)
# tensor([ 0.0275, -0.1498, -0.1000,  0.8381,  0.3568, -0.2047,  0.0186,  0.1723,
#          0.0722, -1.0309], dtype=torch.float64)
# tensor([ 0.0275, -0.1498, -0.0999,  0.8381,  0.3568, -0.2047,  0.0182,  0.1723,
#          0.0724, -1.0309], dtype=torch.float64)
# tensor([ 0.0275, -0.1495, -0.0999,  0.8381,  0.3560, -0.2047,  0.0186,  0.1723,
#          0.0725, -1.0309], dtype=torch.float64)
# tensor([ 0.0275, -0.1542, -0.0991,  0.8384,  0.3560, -0.2047,  0.0190,  0.1723,
#          0.0755, -1.0309], dtype=torch.float64)
# tensor([ 0.0280, -0.1542, -0.0991,  0.8384,  0.3561, -0.2045,  0.0171,  0.1723,
#          0.0768, -1.0309], dtype=torch.float64)
# tensor([ 0.0280, -0.1542, -0.0990,  0.8384,  0.3561, -0.2045,  0.0171,  0.1723,
#          0.0768, -1.0309], dtype=torch.float64)
# tensor([ 0.0280, -0.1542, -0.0990,  0.8384,  0.3558, -0.2045,  0.0171,  0.1724,
#          0.0768, -1.0307], dtype=torch.float64)
# tensor([ 0.0280, -0.1539, -0.0990,  0.8390,  0.3558, -0.2054,  0.0171,  0.1724,
#          0.0768, -1.0307], dtype=torch.float64)
# tensor([ 0.0280, -0.1517, -0.0990,  0.8906,  0.3638, -0.2047,  0.0171,  0.2261,
#          0.0793, -1.1495], dtype=torch.float64)
# tensor([ 0.0280, -0.1543, -0.0990,  0.8926,  0.3641, -0.2045,  0.0171,  0.2261,
#          0.0794, -1.1494], dtype=torch.float64)
# tensor([ 0.0280, -0.1543, -0.0989,  0.8925,  0.3641, -0.2045,  0.0171,  0.2261,
#          0.0794, -1.1494], dtype=torch.float64)
# tensor([ 0.0280, -0.1543, -0.0988,  0.8894,  0.3641, -0.2043,  0.0171,  0.2261,
#          0.0822, -1.1494], dtype=torch.float64)
# tensor([ 0.0286, -0.1418, -0.0762,  0.8986,  0.3643, -0.2043,  0.0171,  0.2300,
#          0.0216, -1.1378], dtype=torch.float64)
# tensor([ 0.0434, -0.1418, -0.0761,  0.9306,  0.3643, -0.2688,  0.0213,  0.2300,
#          0.0349, -1.1377], dtype=torch.float64)
# tensor([ 0.0434, -0.1418, -0.0761,  0.9306,  0.3639, -0.2688,  0.0216,  0.2300,
#          0.0349, -1.1377], dtype=torch.float64)
# tensor([ 0.0434, -0.1398, -0.0496,  0.9372,  0.3639, -0.2688,  0.0216,  0.1943,
#          0.0349, -1.1371], dtype=torch.float64)
# tensor([ 0.0434, -0.1182, -0.0496,  0.9375,  0.3779, -0.2687,  0.0216,  0.1149,
#          0.0356, -1.0944], dtype=torch.float64)
# tensor([ 0.0434, -0.1182, -0.0495,  0.9375,  0.3771, -0.2687,  0.0222,  0.1149,
#          0.0357, -1.0944], dtype=torch.float64)
# tensor([ 0.0435, -0.1181, -0.0842,  0.9696,  0.3771, -0.2687,  0.0222,  0.1155,
#          0.0374, -1.0944], dtype=torch.float64)
# tensor([ 0.0435, -0.1180, -0.0839,  0.9719,  0.3772, -0.2682,  0.0222,  0.1155,
#          0.0340, -1.0943], dtype=torch.float64)
# tensor([ 0.0435, -0.1180, -0.0839,  0.9719,  0.3772, -0.2683,  0.0222,  0.1155,
#          0.0341, -1.0943], dtype=torch.float64)
# tensor([ 0.0435, -0.1180, -0.0835,  0.9721,  0.3772, -0.2682,  0.0222,  0.1155,
#          0.0334, -1.0943], dtype=torch.float64)
# tensor([ 0.0436, -0.1180, -0.0834,  0.9721,  0.3804, -0.2682,  0.0164,  0.1155,
#          0.0359, -1.0942], dtype=torch.float64)
# tensor([ 0.0436, -0.1180, -0.0829,  0.9721,  0.3833, -0.2682,  0.0164,  0.1112,
#          0.0360, -1.0935], dtype=torch.float64)
# tensor([ 0.0436, -0.1180, -0.0829,  0.9720,  0.3833, -0.2682,  0.0164,  0.1112,
#          0.0360, -1.0935], dtype=torch.float64)
# tensor([ 0.0436, -0.1179, -0.0829,  0.9720,  0.3419, -0.2682,  0.0570,  0.1112,
#          0.0361, -1.0928], dtype=torch.float64)
# tensor([ 0.0436, -0.1179, -0.0829,  0.9720,  0.3419, -0.2682,  0.0569,  0.1112,
#          0.0361, -1.0928], dtype=torch.float64)
# tensor([ 0.0436, -0.1228, -0.0786,  0.9721,  0.3419, -0.2682,  0.0570,  0.1112,
#          0.0364, -1.0928], dtype=torch.float64)
# tensor([ 0.0437, -0.1205, -0.0786,  0.9764,  0.3741, -0.2670,  0.0570,  0.1317,
#          0.0389, -1.1558], dtype=torch.float64)
# tensor([ 0.0437, -0.1205, -0.0786,  0.9848,  0.3748, -0.2662,  0.0570,  0.3519,
#          0.0392, -1.3862], dtype=torch.float64)
# tensor([ 0.0438, -0.1205, -0.0786,  0.9848,  0.3748, -0.2662,  0.0569,  0.3519,
#          0.0392, -1.3862], dtype=torch.float64)
# tensor([ 0.0437, -0.1205, -0.0786,  0.9848,  0.3748, -0.2661,  0.0569,  0.3519,
#          0.0392, -1.3862], dtype=torch.float64)
# tensor([ 0.0437, -0.1205, -0.0781,  0.9832,  0.3748, -0.2658,  0.0569,  0.3519,
#          0.0400, -1.3862], dtype=torch.float64)
# tensor([ 0.0438, -0.1204, -0.0781,  0.9853,  0.3779, -0.2531,  0.0569,  0.1045,
#          0.0401, -1.1568], dtype=torch.float64)
# tensor([ 0.0438, -0.1204, -0.0787,  0.9856,  0.3779, -0.2531,  0.0569,  0.1045,
#          0.0404, -1.1568], dtype=torch.float64)
# tensor([ 0.0438, -0.0986, -0.0786,  1.0256,  0.4620, -0.2447,  0.0580,  0.1060,
#         -0.1421, -1.1314], dtype=torch.float64)
# tensor([ 0.0500, -0.0986, -0.2289,  1.0845,  0.4620, -0.2446,  0.0580,  0.1060,
#         -0.0570, -1.1314], dtype=torch.float64)
# tensor([ 0.0500, -0.0986, -0.2288,  1.0939,  0.4677, -0.2445,  0.0580,  0.1070,
#         -0.0468, -1.1580], dtype=torch.float64)
# tensor([ 0.0500, -0.0985, -0.2288,  1.0939,  0.4674, -0.2445,  0.0581,  0.1071,
#         -0.0468, -1.1579], dtype=torch.float64)
# tensor([ 0.0500, -0.0985, -0.2288,  1.0939,  0.4672, -0.2445,  0.0581,  0.1071,
#         -0.0468, -1.1576], dtype=torch.float64)
# tensor([ 0.0500, -0.0985, -0.2288,  1.0939,  0.4672, -0.2445,  0.0580,  0.1071,
#         -0.0467, -1.1576], dtype=torch.float64)
# tensor([ 0.0500, -0.0984, -0.2288,  1.0939,  0.4661, -0.2445,  0.0583,  0.1071,
#         -0.0464, -1.1574], dtype=torch.float64)
# tensor([ 0.0501, -0.0984, -0.2288,  1.0965,  0.4714, -0.2430,  0.0583,  0.1076,
#         -0.0457, -1.1682], dtype=torch.float64)
# tensor([ 0.0501, -0.0785, -0.2005,  1.1651,  0.4714, -0.2430,  0.0583, -0.0747,
#          0.0191, -1.1673], dtype=torch.float64)
# tensor([ 0.0497, -0.0785, -0.2004,  1.1651,  0.4714, -0.2430,  0.0584, -0.0747,
#          0.0192, -1.1673], dtype=torch.float64)
# tensor([ 0.0498, -0.0785, -0.2004,  1.1664,  0.4756, -0.2429,  0.0584, -0.0707,
#          0.0196, -1.1772], dtype=torch.float64)
# tensor([ 0.0503, -0.0785, -0.2027,  1.1679,  0.4756, -0.2429,  0.0584, -0.0707,
#          0.0198, -1.1772], dtype=torch.float64)
# tensor([ 0.0503, -0.0784, -0.2027,  1.1681,  0.4783, -0.2428,  0.0584,  0.0781,
#          0.0198, -1.3291], dtype=torch.float64)
# tensor([ 0.0506, -0.0675, -0.2020,  1.1763,  0.4783, -0.2693,  0.0585,  0.0782,
#          0.0259, -1.3290], dtype=torch.float64)
# tensor([ 0.0506, -0.0683, -0.2017,  1.1763,  0.4783, -0.2693,  0.0585,  0.0785,
#          0.0259, -1.3290], dtype=torch.float64)
# tensor([ 0.0506, -0.0682, -0.2017,  1.1804,  0.4783, -0.2744,  0.0586,  0.0785,
#          0.0268, -1.3290], dtype=torch.float64)
# tensor([ 0.0506, -0.0655, -0.2017,  1.2185,  0.4886, -0.2697,  0.0586,  0.0880,
#          0.0349, -1.4025], dtype=torch.float64)
# tensor([ 0.0507, -0.0728, -0.1993,  1.2191,  0.4887, -0.2697,  0.0586,  0.0898,
#          0.0373, -1.4025], dtype=torch.float64)
# tensor([ 0.0670, -0.0728, -0.2189,  1.2191,  0.4889, -0.2693,  0.0614,  0.0898,
#          0.0374, -1.4024], dtype=torch.float64)
# tensor([ 0.0670, -0.0728, -0.2189,  1.2175,  0.4889, -0.2681,  0.0614,  0.0898,
#          0.0377, -1.4024], dtype=torch.float64)
# tensor([ 0.0671,  0.1753, -0.4686,  1.2180,  0.4889, -0.2681,  0.0619,  0.0898,
#          0.0381, -1.4024], dtype=torch.float64)
# tensor([ 0.0671,  0.1753, -0.4685,  1.2150,  0.4889, -0.2681,  0.0619,  0.0899,
#          0.0409, -1.4023], dtype=torch.float64)
# tensor([ 0.0679,  0.1753, -0.4684,  1.3596,  0.4889, -0.4194,  0.0619,  0.0899,
#          0.0467, -1.4023], dtype=torch.float64)
# tensor([ 0.0679,  0.1753, -0.4684,  1.3609,  0.4902, -0.4192,  0.0619,  0.0905,
#          0.0478, -1.4068], dtype=torch.float64)
# tensor([ 0.0679,  0.1685, -0.4641,  1.3619,  0.4902, -0.4192,  0.0620,  0.0917,
#          0.0480, -1.4068], dtype=torch.float64)
# tensor([ 0.0679,  0.1685, -0.4641,  1.3620,  0.4902, -0.4192,  0.0620,  0.0885,
#          0.0480, -1.4038], dtype=torch.float64)
# tensor([ 0.0679,  0.1685, -0.4641,  1.3620,  0.4903, -0.4192,  0.0617,  0.0885,
#          0.0482, -1.4038], dtype=torch.float64)
# tensor([ 0.0727,  0.1685, -0.4739,  1.3668,  0.4903, -0.4192,  0.0617,  0.0885,
#          0.0484, -1.4038], dtype=torch.float64)
# tensor([ 0.0727,  0.1685, -0.4676,  1.3672,  0.4907, -0.4192,  0.0617,  0.0885,
#          0.0400, -1.4025], dtype=torch.float64)
# tensor([ 0.0737,  0.1685, -0.4795,  1.3779,  0.4907, -0.4192,  0.0617,  0.0886,
#          0.0401, -1.4025], dtype=torch.float64)
# tensor([ 0.0759,  0.1704, -0.5107,  1.3794,  0.4907, -0.4192,  0.0871,  0.0886,
#          0.0403, -1.4025], dtype=torch.float64)
# tensor([ 0.0760,  0.1704, -0.5107,  1.3795,  0.4907, -0.4193,  0.0872,  0.0886,
#          0.0403, -1.4025], dtype=torch.float64)
# tensor([ 0.0758,  0.1704, -0.5107,  1.3795,  0.4907, -0.4193,  0.0873,  0.0886,
#          0.0403, -1.4025], dtype=torch.float64)
# tensor([ 0.0759,  0.1704, -0.5107,  1.3795,  0.4908, -0.4193,  0.0873,  0.0832,
#          0.0403, -1.3973], dtype=torch.float64)
# tensor([ 0.0759,  0.1704, -0.5107,  1.3795,  0.4898, -0.4193,  0.0874,  0.0832,
#          0.0405, -1.3966], dtype=torch.float64)
# tensor([ 0.0759,  0.1704, -0.5107,  1.3973,  0.4907, -0.4136,  0.0874,  0.0920,
#          0.0452, -1.4347], dtype=torch.float64)
# tensor([ 0.0762,  0.1704, -0.5107,  1.3977,  0.4907, -0.4135,  0.0874,  0.0738,
#          0.0452, -1.4171], dtype=torch.float64)
# tensor([ 0.0763,  0.1749, -0.5091,  1.4015,  0.4907, -0.4134,  0.0874,  0.0739,
#          0.0347, -1.4169], dtype=torch.float64)
# tensor([ 0.0763,  0.1749, -0.5049,  1.3952,  0.4907, -0.4134,  0.0874,  0.0739,
#          0.0368, -1.4169], dtype=torch.float64)
# tensor([ 0.0763,  0.1749, -0.5081,  1.3981,  0.4907, -0.4134,  0.0874,  0.0740,
#          0.0369, -1.4169], dtype=torch.float64)
# tensor([ 0.0763,  0.1615, -0.5035,  1.4021,  0.4914, -0.4134,  0.0882,  0.0741,
#          0.0401, -1.4168], dtype=torch.float64)
# tensor([ 0.0763,  0.1572, -0.5026,  1.4021,  0.4925, -0.4134,  0.0882,  0.0760,
#          0.0405, -1.4168], dtype=torch.float64)
# tensor([ 0.0780,  0.1584, -0.5013,  1.4411,  0.4929, -0.3935,  0.0885,  0.0760,
#         -0.0255, -1.4145], dtype=torch.float64)
# tensor([ 0.0780,  0.1584, -0.5013,  1.4392,  0.4929, -0.3935,  0.0885,  0.0760,
#         -0.0236, -1.4145], dtype=torch.float64)
# tensor([ 0.0780,  0.1588, -0.5010,  1.4392,  0.5019, -0.3934,  0.0777,  0.0760,
#         -0.0225, -1.4145], dtype=torch.float64)
# tensor([ 0.0780,  0.1579, -0.5004,  1.4392,  0.5019, -0.3934,  0.0777,  0.0760,
#         -0.0223, -1.4145], dtype=torch.float64)
# tensor([ 0.0779,  0.1579, -0.5004,  1.4392,  0.5019, -0.3934,  0.0777,  0.0760,
#         -0.0223, -1.4145], dtype=torch.float64)
# tensor([ 0.0790,  0.1579, -0.4933,  1.4264,  0.5019, -0.3929,  0.0777,  0.0762,
#         -0.0188, -1.4141], dtype=torch.float64)
# tensor([ 0.0790,  0.1546, -0.4917,  1.4267,  0.5019, -0.3929,  0.0778,  0.0764,
#         -0.0178, -1.4141], dtype=torch.float64)
# tensor([ 0.0789,  0.1546, -0.4917,  1.4267,  0.5019, -0.3929,  0.0778,  0.0764,
#         -0.0178, -1.4141], dtype=torch.float64)
# tensor([ 0.0781,  0.1546, -0.4910,  1.4267,  0.5019, -0.3928,  0.0778,  0.0764,
#         -0.0177, -1.4140], dtype=torch.float64)
# tensor([ 0.0781,  0.1519, -0.4899,  1.4268,  0.5020, -0.3928,  0.0779,  0.0765,
#         -0.0165, -1.4140], dtype=torch.float64)
# tensor([ 0.0781,  0.2763, -0.4896,  1.4285,  0.5033, -0.3927,  0.0779, -0.0765,
#         -0.0138, -1.3915], dtype=torch.float64)
# tensor([ 0.0781,  0.2763, -0.4900,  1.4286,  0.5033, -0.3927,  0.0779, -0.0765,
#         -0.0135, -1.3915], dtype=torch.float64)
# tensor([ 0.0781,  0.2763, -0.4900,  1.4291,  0.5033, -0.3927,  0.0779, -0.0770,
#         -0.0135, -1.3915], dtype=torch.float64)
# tensor([ 0.0781,  0.2763, -0.4899,  1.4291,  0.5033, -0.3927,  0.0779, -0.0770,
#         -0.0135, -1.3915], dtype=torch.float64)
# tensor([ 0.0748,  0.2763, -0.4892,  1.4292,  0.5033, -0.3924,  0.0779, -0.0769,
#         -0.0118, -1.3912], dtype=torch.float64)
# tensor([ 0.0748,  0.2764, -0.4883,  1.4293,  0.4994, -0.3924,  0.0796, -0.0769,
#         -0.0108, -1.3911], dtype=torch.float64)
# tensor([ 0.0749,  0.2764, -0.4883,  1.4293,  0.4994, -0.3924,  0.0795, -0.0769,
#         -0.0106, -1.3911], dtype=torch.float64)
# tensor([ 0.0749,  0.2764, -0.4883,  1.4293,  0.4994, -0.3925,  0.0795, -0.0769,
#         -0.0106, -1.3911], dtype=torch.float64)
# tensor([ 0.0749,  0.2764, -0.4918,  1.4294,  0.4994, -0.3925,  0.0795, -0.0769,
#         -0.0072, -1.3911], dtype=torch.float64)
# tensor([ 0.0749,  0.2764, -0.4918,  1.4294,  0.4994, -0.3925,  0.0794, -0.0769,
#         -0.0072, -1.3911], dtype=torch.float64)
# tensor([ 0.0749,  0.2764, -0.4918,  1.4294,  0.4970, -0.3925,  0.0801, -0.0769,
#         -0.0070, -1.3896], dtype=torch.float64)
# tensor([ 0.0752,  0.2764, -0.4918,  1.4295,  0.4970, -0.3924,  0.0801, -0.0785,
#         -0.0070, -1.3885], dtype=torch.float64)
# tensor([ 0.0941,  0.1714, -0.4633,  1.4491,  0.4970, -0.3924,  0.0801, -0.0703,
#          0.0200, -1.3858], dtype=torch.float64)
# tensor([ 0.0953,  0.1715, -0.4615,  1.4602,  0.4970, -0.3915,  0.0801, -0.0703,
#          0.0048, -1.3857], dtype=torch.float64)
# tensor([ 0.0953,  0.1715, -0.4615,  1.4725,  0.4994, -0.3904,  0.0801, -0.0687,
#          0.0072, -1.4055], dtype=torch.float64)
# tensor([ 0.0954,  0.1715, -0.4613,  1.4834,  0.5018, -0.3900,  0.0801, -0.0664,
#          0.0404, -1.4548], dtype=torch.float64)
# tensor([ 0.0954,  0.1715, -0.4611,  1.2631,  0.5281, -0.2231,  0.0802, -0.0664,
#          0.0622, -1.4500], dtype=torch.float64)
# tensor([ 0.0954,  0.1715, -0.4611,  1.2631,  0.5281, -0.2230,  0.0802, -0.0664,
#          0.0622, -1.4500], dtype=torch.float64)
# tensor([ 0.0954,  0.1716, -0.4606,  1.2631,  0.5281, -0.2230,  0.0802, -0.0683,
#          0.0622, -1.4486], dtype=torch.float64)
# tensor([ 0.0954,  0.1693, -0.4595,  1.2632,  0.5281, -0.2230,  0.0803, -0.0683,
#          0.0632, -1.4486], dtype=torch.float64)
# tensor([-0.0974,  0.1693, -0.4573,  1.2632,  0.5282, -0.2229,  0.2703, -0.0683,
#          0.0635, -1.4486], dtype=torch.float64)
# tensor([-0.0974,  0.1694, -0.4593,  1.2639,  0.5282, -0.2229,  0.2703, -0.0683,
#          0.0646, -1.4486], dtype=torch.float64)
# tensor([-0.1034,  0.1694, -0.4590,  1.2640,  0.5282, -0.2211,  0.2718, -0.0683,
#          0.0665, -1.4481], dtype=torch.float64)
# tensor([-0.1034,  0.1694, -0.4586,  1.2634,  0.5282, -0.2210,  0.2718, -0.0683,
#          0.0667, -1.4481], dtype=torch.float64)
# tensor([-0.0987,  0.1696, -0.4586,  1.3020,  0.5282, -0.3003,  0.2718, -0.0683,
#          0.1023, -1.4481], dtype=torch.float64)
# tensor([-0.0987,  0.1696, -0.4586,  1.3020,  0.5278, -0.3003,  0.2720, -0.0683,
#          0.1023, -1.4480], dtype=torch.float64)
# tensor([-0.0987,  0.1696, -0.4586,  1.3020,  0.5282, -0.3003,  0.2716, -0.0683,
#          0.1024, -1.4480], dtype=torch.float64)
# tensor([-0.0986,  0.1696, -0.4586,  1.3357,  0.5282, -0.3340,  0.2716, -0.0683,
#          0.1024, -1.4480], dtype=torch.float64)
# tensor([-0.0985,  0.3323, -0.4499,  1.3697,  0.5283, -0.3339,  0.2717, -0.0670,
#         -0.1058, -1.4468], dtype=torch.float64)
# tensor([-0.0985,  0.3323, -0.4499,  1.3697,  0.5284, -0.3339,  0.2715, -0.0670,
#         -0.1058, -1.4468], dtype=torch.float64)
# tensor([-0.0985,  0.3323, -0.4495,  1.3693,  0.5284, -0.3339,  0.2715, -0.0670,
#         -0.1058, -1.4468], dtype=torch.float64)
# tensor([-0.0984,  0.3323, -0.4495,  1.3693,  0.5284, -0.3339,  0.2715, -0.0710,
#         -0.1058, -1.4428], dtype=torch.float64)
# tensor([-0.0917,  0.3323, -0.4494,  1.4180,  0.5284, -0.5771,  0.2719, -0.0710,
#          0.0805, -1.4420], dtype=torch.float64)
# tensor([-0.0916,  0.3323, -0.4493,  1.4182,  0.5284, -0.5771,  0.2719, -0.0710,
#          0.0801, -1.4420], dtype=torch.float64)
# tensor([-0.1762,  0.3323, -0.4279,  1.4186,  0.5284, -0.5370,  0.2719, -0.0710,
#          0.1027, -1.4420], dtype=torch.float64)
# tensor([-0.1762,  0.3324, -0.4277,  1.4240,  0.5394, -0.5364,  0.2719, -0.0594,
#          0.1143, -1.4825], dtype=torch.float64)
# tensor([-0.1762,  0.3186, -0.4206,  1.4262,  0.5396, -0.5364,  0.2731, -0.0594,
#          0.1175, -1.4825], dtype=torch.float64)
# tensor([-0.1764,  0.3186, -0.4204,  1.4262,  0.5396, -0.5363,  0.2731, -0.0594,
#          0.1175, -1.4825], dtype=torch.float64)
# tensor([-0.1764,  0.3186, -0.3842,  1.3891,  0.5396, -0.5363,  0.2731, -0.0594,
#          0.1182, -1.4825], dtype=torch.float64)
# tensor([-0.1764,  0.3155, -0.3826,  1.3893,  0.5397, -0.5363,  0.2731, -0.0592,
#          0.1194, -1.4825], dtype=torch.float64)
# tensor([-0.1764,  0.3157, -0.3863,  1.3926,  0.5397, -0.5363,  0.2731, -0.0592,
#          0.1195, -1.4825], dtype=torch.float64)
# tensor([-0.1763,  0.3157, -0.3897,  1.3946,  0.5397, -0.5363,  0.2731, -0.0592,
#          0.1209, -1.4825], dtype=torch.float64)
# tensor([-0.1685,  0.3158, -0.3886,  1.2879,  0.5397, -0.4847,  0.2732, -0.0592,
#          0.1666, -1.4821], dtype=torch.float64)
# tensor([-0.1685,  0.3158, -0.3885,  1.2870,  0.5397, -0.4846,  0.2732, -0.0592,
#          0.1672, -1.4821], dtype=torch.float64)
# tensor([-0.1685,  0.5379, -0.3878,  1.2872,  0.5401, -0.4846,  0.0484, -0.0592,
#          0.1686, -1.4821], dtype=torch.float64)
# tensor([-0.1685,  0.5379, -0.3878,  1.2872,  0.5393, -0.4846,  0.0491, -0.0592,
#          0.1686, -1.4821], dtype=torch.float64)
# tensor([-0.1684,  0.5386, -0.3845,  1.2881,  0.5393, -0.4846,  0.0491, -0.0669,
#          0.1686, -1.4794], dtype=torch.float64)
# tensor([-0.1680,  0.5386, -0.3845,  1.2951,  0.5395, -0.4971,  0.0492, -0.0669,
#          0.1700, -1.4758], dtype=torch.float64)
# tensor([-0.1805,  0.5386, -0.3835,  1.2951,  0.5395, -0.4927,  0.0499, -0.0607,
#          0.1700, -1.4757], dtype=torch.float64)
# tensor([-0.1799,  0.5386, -0.3834,  1.2951,  0.5397, -0.4927,  0.0490, -0.0607,
#          0.1700, -1.4757], dtype=torch.float64)
# tensor([ 0.0044,  0.5395, -0.5703,  1.2961,  0.5397, -0.4925,  0.0495, -0.0607,
#          0.1700, -1.4757], dtype=torch.float64)
# tensor([ 0.0044,  0.5395, -0.5703,  1.2961,  0.5397, -0.4925,  0.0495, -0.0610,
#          0.1700, -1.4754], dtype=torch.float64)
# tensor([ 0.0044,  0.5395, -0.5703,  1.2961,  0.6313, -0.4925,  0.0496, -0.0610,
#          0.1703, -1.5673], dtype=torch.float64)
# tensor([ 0.0047,  0.5395, -0.5688,  1.3013,  0.6313, -0.4925,  0.0496, -0.0610,
#          0.1630, -1.5671], dtype=torch.float64)
# tensor([ 0.0047,  0.5395, -0.5687,  1.3025,  0.6313, -0.6030,  0.0496, -0.0610,
#          0.2722, -1.5671], dtype=torch.float64)
# tensor([ 0.0047,  0.5397, -0.5687,  1.3086,  0.6339, -0.6029,  0.0496, -0.0304,
#          0.2732, -1.6077], dtype=torch.float64)
# tensor([ 0.0048,  0.5402, -0.8187,  1.3091,  0.6339, -0.6029,  0.0496,  0.2179,
#          0.2737, -1.6076], dtype=torch.float64)
# tensor([ 0.0048,  0.5374, -0.8167,  1.3092,  0.6340, -0.6029,  0.0497,  0.2180,
#          0.2740, -1.6076], dtype=torch.float64)
# tensor([ 0.0049,  0.5328, -0.8144,  1.3093,  0.6340, -0.6029,  0.0499,  0.2199,
#          0.2741, -1.6076], dtype=torch.float64)
# tensor([ 0.0049,  0.5331, -0.8142,  1.3093,  0.6316, -0.6029,  0.0513,  0.2199,
#          0.2745, -1.6076], dtype=torch.float64)
# tensor([ 0.0049,  0.5331, -0.8142,  1.3093,  0.6261, -0.6029,  0.0513,  0.2202,
#          0.2746, -1.6026], dtype=torch.float64)
# tensor([ 0.0057,  0.5331, -0.8142,  1.3982,  0.6261, -0.6926,  0.0514,  0.2203,
#          0.2746, -1.6025], dtype=torch.float64)
# tensor([ 0.0062,  0.6073, -0.7894,  1.4093,  0.6285, -0.6923, -0.0726,  0.2203,
#          0.2851, -1.6025], dtype=torch.float64)
# tensor([ 0.0062,  0.6074, -0.7888,  1.4093,  0.6241, -0.6923, -0.0690,  0.2203,
#          0.2852, -1.6025], dtype=torch.float64)
# tensor([ 0.0062,  0.6063, -0.7885,  1.4094,  0.6242, -0.6923, -0.0689,  0.2207,
#          0.2853, -1.6025], dtype=torch.float64)
# tensor([ 0.0062,  0.6063, -0.7898,  1.4106,  0.6242, -0.6923, -0.0689,  0.2207,
#          0.2853, -1.6025], dtype=torch.float64)
# tensor([ 0.0077,  0.6063, -0.7896,  1.4159,  0.6242, -0.7182, -0.0501,  0.2207,
#          0.2855, -1.6025], dtype=torch.float64)
# tensor([ 0.0077,  0.6063, -0.7886,  1.4135,  0.6242, -0.7182, -0.0501,  0.2207,
#          0.2869, -1.6025], dtype=torch.float64)
# tensor([ 0.0078,  0.6068, -0.7886,  1.4169,  0.7970, -0.7178, -0.0500,  0.2277,
#          0.2875, -1.7873], dtype=torch.float64)
# tensor([ 0.0078,  0.6068, -0.7886,  1.4169,  0.7970, -0.7178, -0.0500,  0.2277,
#          0.2875, -1.7873], dtype=torch.float64)
# tensor([ 0.0078,  0.6068, -0.7885,  1.4807,  0.7971, -0.5618, -0.0500,  0.2333,
#          0.2894, -2.0147], dtype=torch.float64)
# tensor([ 0.0077,  0.6068, -0.7885,  1.4807,  0.7971, -0.5618, -0.0500,  0.2333,
#          0.2894, -2.0147], dtype=torch.float64)
# tensor([ 0.0078,  0.6068, -0.7885,  1.7301,  0.7971, -0.8118, -0.0500,  0.2333,
#          0.2898, -2.0147], dtype=torch.float64)
# tensor([ 0.0078,  0.6068, -0.7882,  1.7333,  0.8006, -0.8115, -0.0500,  0.2401,
#          0.3000, -2.0390], dtype=torch.float64)
# tensor([ 0.0078,  0.6068, -0.7881,  1.7333,  0.8008, -0.8114, -0.0559,  0.2401,
#          0.3055, -2.0390], dtype=torch.float64)
# tensor([ 0.0087,  0.6072, -0.7881,  1.7881,  0.8013, -0.8726, -0.0557,  0.2403,
#          0.3063, -2.0354], dtype=torch.float64)
# tensor([ 0.0087,  0.6072, -0.7880,  1.7881,  0.8013, -0.8726, -0.0557,  0.2401,
#          0.3063, -2.0354], dtype=torch.float64)
# tensor([ 0.0087,  0.6075, -0.7879,  1.7881,  0.7997, -0.8726, -0.0546,  0.2401,
#          0.3064, -2.0354], dtype=torch.float64)
# tensor([ 0.0087,  0.6069, -0.7877,  1.7881,  0.7997, -0.8726, -0.0544,  0.2402,
#          0.3066, -2.0354], dtype=torch.float64)
# tensor([ 0.0087,  0.6069, -0.7869,  1.7872,  0.7997, -0.8726, -0.0544,  0.2402,
#          0.3067, -2.0354], dtype=torch.float64)
# tensor([ 0.0087,  0.6087, -0.7855,  1.7877,  0.7636, -0.8726, -0.0251,  0.2402,
#          0.3085, -2.0343], dtype=torch.float64)
# tensor([ 0.0086,  0.6087, -0.7854,  1.7877,  0.7636, -0.8726, -0.0251,  0.2402,
#          0.3085, -2.0343], dtype=torch.float64)
# tensor([ 0.0086,  0.6087, -0.7854,  1.7877,  0.7633, -0.8726, -0.0250,  0.2402,
#          0.3086, -2.0341], dtype=torch.float64)
# tensor([ 0.0086,  0.6088, -0.7845,  1.7881,  0.7633, -0.8725, -0.0250,  0.2402,
#          0.3072, -2.0341], dtype=torch.float64)
# tensor([ 0.0085,  0.6088, -0.7844,  1.7881,  0.7633, -0.8725, -0.0250,  0.2402,
#          0.3072, -2.0341], dtype=torch.float64)
# tensor([ 0.0085,  0.6088, -0.7844,  1.7881,  0.7631, -0.8725, -0.0248,  0.2403,
#          0.3072, -2.0341], dtype=torch.float64)
# tensor([ 0.0085,  0.6088, -0.7844,  1.7867,  0.7631, -0.8714, -0.0248,  0.2403,
#          0.3074, -2.0341], dtype=torch.float64)
# tensor([ 0.0085,  0.6088, -0.7844,  1.7867,  0.7633, -0.8714, -0.0251,  0.2403,
#          0.3075, -2.0341], dtype=torch.float64)
# tensor([ 0.0095,  0.6950, -0.7753,  1.8122,  0.7634, -0.8711, -0.0250,  0.2404,
#          0.1849, -2.0339], dtype=torch.float64)
# tensor([ 0.0096,  0.6950, -0.7753,  1.8122,  0.7634, -0.8711, -0.0250,  0.2280,
#          0.1850, -2.0217], dtype=torch.float64)
# tensor([ 0.0097,  0.6950, -0.7752,  1.8122,  0.7638, -0.8711, -0.0257,  0.2280,
#          0.1850, -2.0217], dtype=torch.float64)
# tensor([ 0.0097,  0.6950, -0.7752,  1.8122,  0.7638, -0.8711, -0.0257,  0.2280,
#          0.1850, -2.0217], dtype=torch.float64)
# tensor([ 0.0097,  0.6954, -0.7752,  1.8153,  0.7639, -0.8711, -0.0257,  0.3685,
#          0.1850, -2.1659], dtype=torch.float64)
# tensor([ 0.0098,  0.6954, -0.7752,  1.8154,  0.7640, -0.8711, -0.0257,  0.3501,
#          0.1851, -2.1477], dtype=torch.float64)
# tensor([ 0.0106,  0.6954, -0.7752,  1.8186,  0.7640, -0.8751, -0.0257,  0.3501,
#          0.1851, -2.1477], dtype=torch.float64)
# tensor([ 0.0106,  0.6955, -0.7750,  1.8187,  0.7640, -0.8751, -0.0257,  0.3435,
#          0.1851, -2.1416], dtype=torch.float64)
# tensor([ 0.0106,  0.6955, -0.7812,  1.8187,  0.7640, -0.8751, -0.0257,  0.3435,
#          0.1912, -2.1416], dtype=torch.float64)
# tensor([ 0.0106,  0.6928, -0.7789,  1.8188,  0.7640, -0.8751, -0.0257,  0.3436,
#          0.1915, -2.1416], dtype=torch.float64)
# tensor([ 0.0106,  0.6917, -0.7784,  1.8191,  0.7640, -0.8751, -0.0257,  0.3438,
#          0.1915, -2.1416], dtype=torch.float64)
# tensor([ 0.0110,  0.6917, -0.7782,  1.8191,  0.7643, -0.8751, -0.0265,  0.3438,
#          0.1915, -2.1416], dtype=torch.float64)
# tensor([ 0.0110,  0.6917, -0.7782,  1.8191,  0.7643, -0.8750, -0.0263,  0.3438,
#          0.1912, -2.1416], dtype=torch.float64)
# tensor([ 0.0110,  0.6918, -0.7781,  1.8207,  0.7755, -0.8747, -0.0263,  0.3443,
#          0.2063, -2.1704], dtype=torch.float64)
# tensor([ 0.0110,  0.6918, -0.7781,  1.8207,  0.7733, -0.8742, -0.0248,  0.3443,
#          0.2064, -2.1703], dtype=torch.float64)
# tensor([ 0.0110,  0.6904, -0.7773,  1.8207,  0.7734, -0.8742, -0.0248,  0.3444,
#          0.2066, -2.1703], dtype=torch.float64)
# tensor([ 0.0110,  0.6904, -0.7773,  1.9948,  0.7735, -1.0570, -0.0248,  0.3444,
#          0.2132, -2.1683], dtype=torch.float64)
# tensor([ 0.0111,  0.6905, -0.7820,  1.9952,  0.7735, -1.0570, -0.0244,  0.3444,
#          0.2170, -2.1683], dtype=torch.float64)
# tensor([ 0.0111,  0.6910, -0.7893,  1.9999,  0.7735, -1.0570, -0.0244,  0.3449,
#          0.2185, -2.1683], dtype=torch.float64)
# tensor([ 0.0112,  0.6911, -0.7892,  2.0020,  0.8632, -1.0568, -0.0244,  0.3462,
#          0.2352, -2.2785], dtype=torch.float64)
# tensor([ 0.0111,  0.6911, -0.7892,  2.0020,  0.8632, -1.0568, -0.0244,  0.3462,
#          0.2353, -2.2785], dtype=torch.float64)
# tensor([ 0.0112,  0.6911, -0.7878,  2.0004,  0.8632, -1.0568, -0.0244,  0.3462,
#          0.2354, -2.2785], dtype=torch.float64)
# tensor([ 0.0114,  0.6911, -0.7875,  2.0013,  0.8651, -1.0567, -0.0244,  0.3497,
#          0.2371, -2.2870], dtype=torch.float64)
# tensor([ 0.0114,  0.6911, -0.7875,  2.0013,  0.8655, -1.0567, -0.0248,  0.3497,
#          0.2371, -2.2870], dtype=torch.float64)
# tensor([ 0.0114,  0.6911, -0.7306,  2.0428,  0.8655, -1.0567, -0.0248,  0.2430,
#          0.2382, -2.2800], dtype=torch.float64)
# tensor([ 0.0115,  0.6911, -0.7481,  2.0429,  0.8655, -1.0567, -0.0247,  0.2430,
#          0.2554, -2.2800], dtype=torch.float64)
# tensor([ 0.0115,  0.6911, -0.7481,  2.0429,  0.8655, -1.0567, -0.0247,  0.2430,
#          0.2554, -2.2800], dtype=torch.float64)
# tensor([ 0.0115,  0.6911, -0.7476,  2.0422,  0.8655, -1.0567, -0.0247,  0.2430,
#          0.2555, -2.2800], dtype=torch.float64)
# tensor([ 0.0143,  0.6911, -0.7476,  2.0424,  0.8665, -1.0739, -0.0208,  0.2430,
#          0.2647, -2.2797], dtype=torch.float64)
# ...
#          -7.8033,  10.5908, -19.1700], dtype=torch.float64)
# tensor([  3.8008,   6.7719,  -4.1073,  14.5049,   7.8693, -14.6057,   2.1486,
#          -7.8033,  10.5908, -19.1700], dtype=torch.float64)
# tensor([  3.8675,   6.7722,  -4.1073,  14.5051,   7.8693, -14.6741,   2.1487,
#          -7.8024,  10.5909, -19.1698], dtype=torch.float64)
# tensor([  3.8787,   6.7722,  -4.1266,  14.5116,   7.8693, -14.6741,   2.1502,
#          -7.8024,  10.5911, -19.1698], dtype=torch.float64)
# tensor([  3.9883,   6.7785,  -4.1260,  14.5116,   7.8694, -14.6735,   2.0326,
#          -7.8024,  10.5914, -19.1698], dtype=torch.float64)
# tensor([  3.9884,   6.7788,  -4.0306,  14.5613,   7.8694, -14.6735,   2.0326,
#          -7.9672,  10.6080, -19.1673], dtype=torch.float64)
# tensor([  3.9884,   6.7788,  -4.0306,  14.5620,   7.8694, -14.6743,   2.0326,
#          -7.9672,  10.6081, -19.1672], dtype=torch.float64)
# tensor([  3.9884,   6.7772,  -4.0300,  14.5622,   7.8697, -14.6743,   2.0326,
#          -7.9670,  10.6083, -19.1672], dtype=torch.float64)
# tensor([  3.9883,   6.7772,  -4.0300,  14.5622,   7.8697, -14.6743,   2.0326,
#          -7.9670,  10.6083, -19.1672], dtype=torch.float64)
# tensor([  3.9884,   6.7772,  -4.0300,  14.5621,   7.8697, -14.6742,   2.0326,
#          -7.9669,  10.6083, -19.1672], dtype=torch.float64)
# tensor([  4.0032,   6.7772,  -4.0274,  14.5621,   7.8698, -14.6741,   2.0144,
#          -7.9669,  10.6088, -19.1672], dtype=torch.float64)
# tensor([  4.0032,   6.7772,  -4.0274,  14.5625,   7.9309, -14.6710,   2.0145,
#          -7.9669,  10.6097, -19.2326], dtype=torch.float64)
# tensor([  4.0032,   6.7722,  -4.0237,  14.5625,   7.9313, -14.6710,   2.0145,
#          -7.9663,  10.6100, -19.2326], dtype=torch.float64)
# tensor([  4.0032,   6.7714,  -4.0233,  14.5626,   7.9313, -14.6710,   2.0146,
#          -7.9661,  10.6101, -19.2326], dtype=torch.float64)
# tensor([  4.0032,   6.7717,  -4.0233,  14.5626,   7.9270, -14.6710,   2.0146,
#          -7.9654,  10.6102, -19.2295], dtype=torch.float64)
# tensor([  4.0032,   6.7717,  -4.0233,  14.5626,   7.8574, -14.6709,   2.0146,
#          -7.9654,  10.6103, -19.1602], dtype=torch.float64)
# tensor([  4.0032,   6.7707,  -4.0228,  14.5626,   7.8575, -14.6709,   2.0146,
#          -7.9650,  10.6103, -19.1602], dtype=torch.float64)
# tensor([  4.0032,   6.7707,  -4.0227,  14.5625,   7.8575, -14.6709,   2.0146,
#          -7.9650,  10.6104, -19.1602], dtype=torch.float64)
# tensor([  4.0032,   6.7686,  -4.0225,  14.5625,   7.8578, -14.6709,   2.0146,
#          -7.9635,  10.6104, -19.1602], dtype=torch.float64)
# tensor([  4.0032,   6.7686,  -4.0224,  14.5355,   7.8578, -14.6519,   2.0146,
#          -7.9635,  10.6183, -19.1602], dtype=torch.float64)
# tensor([  4.0034,   6.7700,  -4.0381,  14.5376,   7.8606, -14.6519,   2.0168,
#          -7.9635,  10.6251, -19.1601], dtype=torch.float64)
# tensor([  4.0034,   6.7700,  -4.0370,  14.5400,   7.8606, -14.6515,   2.0171,
#          -7.9635,  10.6209, -19.1601], dtype=torch.float64)
# tensor([  4.0037,   6.7897,  -4.0350,  14.5509,   7.8606, -14.6512,   2.0171,
#          -7.9634,  10.5875, -19.1600], dtype=torch.float64)
# tensor([  4.0037,   6.7897,  -4.0348,  14.5524,   7.8606, -14.6512,   2.0171,
#          -7.9654,  10.5875, -19.1598], dtype=torch.float64)
# tensor([  4.0038,   6.7897,  -4.0350,  14.5525,   7.8606, -14.6512,   2.0171,
#          -7.9654,  10.5875, -19.1598], dtype=torch.float64)
# tensor([  4.0039,   6.7897,  -4.0350,  14.7227,   7.8606, -14.8219,   2.0171,
#          -7.9654,  10.5880, -19.1597], dtype=torch.float64)
# tensor([  4.0040,   6.7897,  -4.0350,  14.7227,   7.8607, -14.8219,   2.0170,
#          -7.9654,  10.5880, -19.1597], dtype=torch.float64)
# tensor([  4.0041,   6.7861,  -4.0338,  14.7227,   7.8607, -14.8219,   2.0188,
#          -7.9654,  10.5884, -19.1597], dtype=torch.float64)
# tensor([  4.0041,   6.7854,  -4.0334,  14.7227,   7.8607, -14.8219,   2.0188,
#          -7.9652,  10.5885, -19.1597], dtype=torch.float64)
# tensor([  4.0040,   6.7854,  -4.0334,  14.7227,   7.8607, -14.8219,   2.0188,
#          -7.9652,  10.5885, -19.1597], dtype=torch.float64)
# tensor([  4.0041,   6.7855,  -4.0334,  14.7233,   7.8608, -14.8229,   2.0188,
#          -7.9652,  10.5887, -19.1596], dtype=torch.float64)
# tensor([  4.0041,   6.7856,  -4.0363,  14.7254,   7.8608, -14.8229,   2.0189,
#          -7.9652,  10.5891, -19.1596], dtype=torch.float64)
# tensor([  4.0040,   6.7856,  -4.0363,  14.7254,   7.8608, -14.8229,   2.0189,
#          -7.9652,  10.5891, -19.1596], dtype=torch.float64)
# tensor([  4.0041,   6.7856,  -4.0363,  14.7255,   7.8626, -14.8228,   2.0189,
#          -7.9650,  10.5893, -19.1619], dtype=torch.float64)
# tensor([  4.0042,   6.7650,  -4.0288,  14.7262,   7.8626, -14.8228,   2.0192,
#          -7.9650,  10.6011, -19.1619], dtype=torch.float64)
# tensor([  4.0033,   6.7650,  -4.0285,  14.7262,   7.8627, -14.8228,   2.0198,
#          -7.9650,  10.6011, -19.1619], dtype=torch.float64)
# tensor([  4.0033,   6.7650,  -4.0287,  14.7263,   7.8627, -14.8228,   2.0198,
#          -7.9650,  10.6012, -19.1619], dtype=torch.float64)
# tensor([  4.0738,   6.7671,  -4.0025,  14.7264,   7.8748, -14.8225,   2.0206,
#          -7.9449,  10.4482, -19.1410], dtype=torch.float64)
# tensor([  4.0738,   6.7671,  -4.0025,  14.7261,   7.8748, -14.8223,   2.0206,
#          -7.9449,  10.4483, -19.1410], dtype=torch.float64)
# tensor([  4.0738,   6.7671,  -4.0025,  14.7262,   7.8748, -14.8222,   2.0203,
#          -7.9449,  10.4483, -19.1410], dtype=torch.float64)
# tensor([  4.0738,   6.7671,  -4.0025,  14.7262,   7.8745, -14.8222,   2.0204,
#          -7.9449,  10.4484, -19.1408], dtype=torch.float64)
# tensor([  4.0738,   6.7674,  -4.0085,  14.7307,   7.8745, -14.8222,   2.0205,
#          -7.9449,  10.4495, -19.1408], dtype=torch.float64)
# tensor([  4.0738,   6.7674,  -4.0085,  14.7309,   7.8745, -14.8224,   2.0205,
#          -7.9449,  10.4495, -19.1408], dtype=torch.float64)
# tensor([  4.0739,   6.7674,  -4.0085,  14.7294,   7.8745, -14.8210,   2.0205,
#          -7.9449,  10.4495, -19.1408], dtype=torch.float64)
# tensor([  4.0739,   6.7674,  -4.0085,  14.7294,   7.8745, -14.8210,   2.0202,
#          -7.9449,  10.4498, -19.1408], dtype=torch.float64)
# tensor([  4.0739,   6.7675,  -4.0086,  14.7294,   7.8745, -14.8210,   2.0202,
#          -7.9449,  10.4498, -19.1408], dtype=torch.float64)
# tensor([  4.0739,   6.7675,  -4.0086,  14.7315,   7.9678, -14.8149,   2.0202,
#          -8.1916,  10.4503, -18.9961], dtype=torch.float64)
# tensor([  4.0779,   6.7675,  -3.9974,  14.7328,   7.9678, -14.8407,   2.0204,
#          -8.1915,  10.4593, -18.9960], dtype=torch.float64)
# tensor([  4.0780,   6.7675,  -3.9969,  14.7914,   7.9678, -14.8405,   2.0204,
#          -8.1915,  10.3998, -18.9959], dtype=torch.float64)
# tensor([  4.0780,   6.7706,  -4.0307,  14.8192,   7.9678, -14.8405,   2.0205,
#          -8.1915,  10.4027, -18.9959], dtype=torch.float64)
# tensor([  4.0781,   6.7706,  -4.0305,  14.8201,   7.9791, -14.8403,   2.0205,
#          -8.1879,  10.4054, -19.0150], dtype=torch.float64)
# tensor([  4.0796,   6.7706,  -4.0300,  14.8294,   7.9816, -14.8054,   2.0216,
#          -8.1879,  10.3522, -19.0116], dtype=torch.float64)
# tensor([  4.0794,   6.7706,  -4.0299,  14.8294,   7.9816, -14.8054,   2.0216,
#          -8.1879,  10.3522, -19.0116], dtype=torch.float64)
# tensor([  4.0795,   6.7724,  -4.0297,  14.8297,   7.9829, -14.8053,   2.0157,
#          -8.1879,  10.3543, -19.0116], dtype=torch.float64)
# tensor([  4.0795,   6.7711,  -4.0294,  14.8299,   7.9829, -14.8053,   2.0157,
#          -8.1874,  10.3544, -19.0116], dtype=torch.float64)
# tensor([  4.0796,   6.7716,  -4.0271,  14.8317,   8.1491, -14.8051,   2.0160,
#          -8.1852,  10.3574, -19.1880], dtype=torch.float64)
# tensor([  4.0798,   6.7716,  -4.0273,  14.8317,   8.1491, -14.8051,   2.0160,
#          -8.1852,  10.3574, -19.1880], dtype=torch.float64)
# tensor([  4.0689,   6.7716,  -4.0272,  14.8317,   8.1491, -14.7945,   2.0160,
#          -8.1852,  10.3575, -19.1880], dtype=torch.float64)
# tensor([  4.0689,   6.7716,  -4.0272,  14.8316,   8.1491, -14.7944,   2.0160,
#          -8.1852,  10.3576, -19.1880], dtype=torch.float64)
# tensor([  4.0689,   6.7707,  -4.0268,  14.8316,   8.1492, -14.7944,   2.0160,
#          -8.1848,  10.3576, -19.1880], dtype=torch.float64)
# tensor([  4.0689,   6.7664,  -4.0244,  14.8318,   8.1496, -14.7944,   2.0161,
#          -8.1840,  10.3579, -19.1879], dtype=torch.float64)
# tensor([  4.0689,   6.7664,  -4.0244,  14.8443,   8.1502, -14.7931,   2.0161,
#          -8.1751,  10.3580, -19.2113], dtype=torch.float64)
# tensor([  4.0689,   6.7664,  -4.0244,  14.8446,   8.1502, -14.7936,   2.0161,
#          -8.1751,  10.3581, -19.2113], dtype=torch.float64)
# tensor([  4.0689,   6.7664,  -4.0243,  14.8446,   8.1502, -14.7935,   2.0161,
#          -8.1751,  10.3581, -19.2113], dtype=torch.float64)
# tensor([  4.0689,   6.7664,  -4.0243,  14.8446,   8.1502, -14.7935,   2.0161,
#          -8.1751,  10.3582, -19.2113], dtype=torch.float64)
# tensor([  4.0690,   6.8170,  -4.0240,  14.8666,   8.1561, -14.7935,   2.0161,
#          -8.1056,  10.3731, -19.3747], dtype=torch.float64)
# tensor([  4.0690,   6.8170,  -4.0240,  14.8680,   8.1561, -14.7933,   2.0161,
#          -8.1113,  10.3731, -19.3706], dtype=torch.float64)
# tensor([  4.0690,   6.8172,  -4.0214,  14.8891,   8.1565, -14.7897,   2.0161,
#          -8.1113,  10.3443, -19.3700], dtype=torch.float64)
# tensor([  4.0690,   6.8172,  -4.0212,  14.8920,   8.1565, -14.7888,   2.0162,
#          -8.1113,  10.3404, -19.3700], dtype=torch.float64)
# tensor([  4.0690,   6.8166,  -4.0210,  14.8920,   8.1566, -14.7888,   2.0162,
#          -8.1111,  10.3404, -19.3700], dtype=torch.float64)
# tensor([  4.0649,   6.8166,  -4.0210,  14.8931,   8.1566, -14.7862,   2.0163,
#          -8.1111,  10.3408, -19.3700], dtype=torch.float64)
# tensor([  4.0649,   6.8147,  -4.0203,  14.8934,   8.1567, -14.7862,   2.0163,
#          -8.1103,  10.3409, -19.3699], dtype=torch.float64)
# tensor([  4.0649,   6.8057,  -4.0185,  14.8935,   8.1569, -14.7862,   2.0169,
#          -8.1103,  10.3469, -19.3699], dtype=torch.float64)
# tensor([  4.0649,   6.8057,  -4.0185,  14.8934,   8.1569, -14.7862,   2.0169,
#          -8.1103,  10.3469, -19.3699], dtype=torch.float64)
# tensor([  4.0654,   6.8057,  -4.0190,  14.8935,   8.1569, -14.7862,   2.0169,
#          -8.1103,  10.3469, -19.3699], dtype=torch.float64)
# tensor([  4.0654,   6.8057,  -4.0190,  14.8935,   8.1517, -14.7862,   2.0181,
#          -8.1103,  10.3470, -19.3659], dtype=torch.float64)
# tensor([  4.0654,   6.8057,  -4.0190,  14.8934,   8.1517, -14.7861,   2.0181,
#          -8.1103,  10.3470, -19.3659], dtype=torch.float64)
# tensor([  4.0641,   6.8057,  -4.0184,  14.8934,   8.1517, -14.7861,   2.0186,
#          -8.1102,  10.3470, -19.3658], dtype=torch.float64)
# tensor([  4.0641,   6.8057,  -4.0184,  14.8934,   8.1514, -14.7861,   2.0186,
#          -8.1102,  10.3470, -19.3657], dtype=torch.float64)
# tensor([  4.0089,   6.8057,  -4.0155,  14.8934,   8.1515, -14.7861,   2.0710,
#          -8.1102,  10.3471, -19.3657], dtype=torch.float64)
# tensor([  4.0089,   6.8057,  -4.0155,  14.8934,   8.1515, -14.7862,   2.0710,
#          -8.1102,  10.3471, -19.3657], dtype=torch.float64)
# tensor([  4.0089,   6.8057,  -4.0155,  14.8762,   8.1515, -14.7861,   2.0710,
#          -8.1102,  10.3642, -19.3656], dtype=torch.float64)
# tensor([  4.0090,   6.8058,  -4.0096,  14.8766,   8.1525, -14.7860,   2.0576,
#          -8.1102,  10.3699, -19.3655], dtype=torch.float64)
# tensor([  4.0090,   6.8058,  -4.0096,  14.8767,   8.1525, -14.7859,   2.0576,
#          -8.1102,  10.3698, -19.3655], dtype=torch.float64)
# tensor([  4.0090,   6.8058,  -4.0096,  14.9178,   8.1526, -14.7854,   2.0576,
#          -8.2501,  10.3699, -19.2675], dtype=torch.float64)
# tensor([  4.0090,   6.8058,  -4.0096,  14.9179,   8.1526, -14.7854,   2.0576,
#          -8.2509,  10.3699, -19.2668], dtype=torch.float64)
# tensor([  4.0090,   6.8058,  -4.0096,  14.9179,   8.1526, -14.7853,   2.0576,
#          -8.2509,  10.3697, -19.2668], dtype=torch.float64)
# tensor([  4.0090,   6.8058,  -4.0096,  14.9183,   8.1526, -14.7852,   2.0576,
#          -8.2577,  10.3697, -19.2604], dtype=torch.float64)
# tensor([  4.0090,   6.8086,  -4.0095,  14.9362,   8.1582, -14.7841,   2.0576,
#          -8.2436,  10.3840, -19.3163], dtype=torch.float64)
# tensor([  4.0090,   6.8086,  -4.0095,  14.9362,   8.1582, -14.7841,   2.0576,
#          -8.2436,  10.3840, -19.3163], dtype=torch.float64)
# tensor([  4.0090,   6.8086,  -4.0094,  14.9362,   8.1582, -14.7841,   2.0574,
#          -8.2436,  10.3840, -19.3163], dtype=torch.float64)
# tensor([  4.0090,   6.8086,  -4.0094,  14.9362,   8.1411, -14.7840,   2.0577,
#          -8.2436,  10.3848, -19.3004], dtype=torch.float64)
# tensor([  4.0090,   6.8086,  -4.0094,  14.9362,   8.1410, -14.7840,   2.0577,
#          -8.2436,  10.3848, -19.3003], dtype=torch.float64)
# tensor([  4.0091,   6.8882,  -3.8747,  14.6862,   8.1411, -14.7839,   2.0577,
#          -8.2396,  10.4156, -19.2997], dtype=torch.float64)
# tensor([  4.0093,   6.8882,  -3.8877,  14.6864,   8.1411, -14.7839,   2.0581,
#          -8.2396,  10.4279, -19.2997], dtype=torch.float64)
# tensor([  4.0093,   6.8848,  -3.8874,  14.6864,   8.1411, -14.7839,   2.0608,
#          -8.2396,  10.4282, -19.2997], dtype=torch.float64)
# tensor([  4.0093,   6.8848,  -3.8874,  14.6864,   8.1411, -14.7839,   2.0608,
#          -8.2396,  10.4282, -19.2997], dtype=torch.float64)
# tensor([  4.0095,   6.8849,  -3.8874,  14.6895,   8.1411, -14.7822,   2.0608,
#          -8.2394,  10.4196, -19.2964], dtype=torch.float64)
# tensor([  4.0095,   6.8849,  -3.8874,  14.6895,   8.1406, -14.7822,   2.0612,
#          -8.2394,  10.4196, -19.2963], dtype=torch.float64)
# tensor([  4.0090,   6.8849,  -3.8870,  14.6895,   8.1406, -14.7822,   2.0612,
#          -8.2394,  10.4197, -19.2963], dtype=torch.float64)
# tensor([  4.0111,   6.8851,  -3.8870,  14.6915,   8.1488, -14.7628,   2.0614,
#          -8.3406,  10.4198, -19.2273], dtype=torch.float64)
# tensor([  4.0444,   7.0483,  -3.8860,  14.6976,   8.1489, -15.0059,   2.0615,
#          -8.3229,  10.4387, -19.2244], dtype=torch.float64)
# tensor([  4.0444,   7.0483,  -3.8860,  14.7026,   8.1491, -15.0133,   2.0616,
#          -8.3229,  10.4406, -19.2244], dtype=torch.float64)
# tensor([  4.0444,   7.0496,  -3.8859,  14.7754,   8.1678, -15.0016,   2.0617,
#          -8.3225,  10.4502, -19.3390], dtype=torch.float64)
# tensor([  4.0444,   7.0496,  -3.8859,  14.7758,   8.1678, -15.0030,   2.0619,
#          -8.3225,  10.4510, -19.3390], dtype=torch.float64)
# tensor([  4.0444,   7.0496,  -3.8859,  14.9140,   8.1678, -15.1416,   2.0619,
#          -8.3225,  10.4514, -19.3389], dtype=torch.float64)
# tensor([  4.0444,   7.0496,  -3.8859,  14.9140,   8.1675, -15.1416,   2.0619,
#          -8.3225,  10.4514, -19.3386], dtype=torch.float64)
# tensor([  4.0444,   7.0496,  -3.8783,  14.9143,   8.1675, -15.1416,   2.0619,
#          -8.3306,  10.4514, -19.3386], dtype=torch.float64)
# tensor([  4.0445,   7.0496,  -3.8783,  14.9153,   8.1675, -15.1416,   2.0619,
#          -8.3426,  10.4514, -19.3276], dtype=torch.float64)
# tensor([  4.0445,   7.0504,  -3.9614,  14.9307,   8.1732, -15.1416,   2.0710,
#          -8.3426,  10.5034, -19.3276], dtype=torch.float64)
# tensor([  4.0445,   7.0504,  -3.9611,  14.9366,   8.1732, -15.1414,   2.0710,
#          -8.3426,  10.4969, -19.3275], dtype=torch.float64)
# tensor([  4.0445,   7.0197,  -3.9574,  14.9373,   8.1854, -15.1414,   2.0723,
#          -8.3426,  10.5096, -19.3275], dtype=torch.float64)
# tensor([  4.0446,   7.0197,  -3.9573,  14.9375,   8.1861, -15.1414,   2.0723,
#          -8.3417,  10.5099, -19.3297], dtype=torch.float64)
# tensor([  4.0447,   7.0197,  -3.9573,  14.9375,   8.1861, -15.1414,   2.0713,
#          -8.3417,  10.5107, -19.3297], dtype=torch.float64)
# tensor([  4.0447,   7.0197,  -3.9573,  14.9375,   8.1861, -15.1414,   2.0713,
#          -8.3417,  10.5107, -19.3297], dtype=torch.float64)
# tensor([  4.0454,   7.0198,  -3.9511,  14.9572,   8.1861, -15.3876,   2.2769,
#          -8.3417,  10.5247, -19.3297], dtype=torch.float64)
# Train Epoch: 1 [102144/60000 (6%)]	Loss: 2.022322
